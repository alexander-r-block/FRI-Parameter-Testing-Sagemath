# %%
# 1000 bits of floating point precision
RR = RealField(1000)

# log base 2 function
def log2(x): return log(x,2)

# helper function for computing proof size
def bits_to_bytes(x):
    byts = x/8
    KiB = 2^(10)
    MiB = 2^(20)
    GiB = 2^(30)
    TiB = 2^(40)
    if(byts < KiB):
        return "{} B".format(floor(byts))
    elif(byts < MiB):
        return "{} KiB".format(floor(byts/KiB))
    elif(byts < GiB):
        return "{} MiB".format(RR(byts/MiB).str(digits=3))
    elif(byts < TiB):
        return "{} GiB".format(RR(byts/GiB).str(digits=3))
    else:
        return "{} TiB".format(RR(byts/TiB).str(digits=3))


"""
    Compute proof sizes of FRI + Merkle.
    
    Parameters
        hash_out: output length of the hash function/random oracle
        ell: number of verifier repetitions during the query phase
        k: log2(message_length) / log2(degree_bound) (i.e., polynomials of degree < 2^k)
        n: log2(domain_size) (i.e., domain size = 2^n)
        F: lower bound or exact size of the finite field
"""
def proof_size(hash_out, ell, k, n, F):
    f_bits = (2*k*ell+1)*ceil(log2(F))
    hash_number = k + ell*( (n+1)*(n+2) - (n-k+1)*(n-k+2) )
    hash_bits = hash_out*hash_number
    
    total_bits = f_bits + hash_bits
    return(bits_to_bytes(total_bits))


"""
    Comptue batched proof sizes of FRI + Merkle. Assumes *good* batching
        (i.e., verifier sends distinct challenges for each polynomial 
        to batch).
    
    Parameters
        hash_out: output length of the hash function/random oracle
        ell: number of verifier repetitions during the query phase
        k: log2(message_length) / log2(degree_bound) (i.e., polynomials of degree < 2^k)
        n: log2(domain_size) (i.e., domain size = 2^n)
        F: lower bound or exact size of the finite field
        t: number of polynomials to batch
"""
def batch_proof_size(hash_out, ell, k, n, F, t):
    f_bits = (2*ell*(k+t)+1)*ceil(log2(F))
    hash_number = k + ell*( (n+1)*(n+2) - (n-k+1)*(n-k+2) ) + t*(1 + 2*ell*(n+1))
    hash_bits = hash_out * hash_number
    
    total_bits = f_bits + hash_bits
    return(bits_to_bytes(total_bits))




#### PART 1 CALCULATIONS ####

# function to calculte maximum value for nu for provable security calculations
#     since nu is the min of two parameters of the rbr soundness, one of which
#     is decreasing in m and the other is increasing in m
def calc_max_nu_m(N, k, rho, F, ell, z):
    m = 3
    delta = 1-sqrt(rho)*(1+(1/(2*m)))
    rbr1 = (1/4)*( ( ((m+1/2)^7) * (N^2) ) / (3*(rho^(3/2))*F) ) + ((2*m+1)*(N+1)) / (sqrt(rho)*F)
    rbr2 = ((1-delta)^ell) / (2^z)
    
    while(rbr1 <= rbr2):
        m = 2*m
        delta = 1-sqrt(rho)*(1+(1/(2*m)))
        rbr1 = (1/4)*( ( ((m+1/2)^7) * (N^2) ) / (3*(rho^(3/2))*F) ) + ((2*m+1)*(N+1)) / (sqrt(rho)*F)
        rbr2 = (1-delta)^ell

    # do binary search followed by linear scan
    m_upper = m
    m_lower = m/2
    while(m_upper - m_lower > 200): 
        m = floor((m_upper + m_lower) / 2) # this is the midpoint
        delta = 1-sqrt(rho)*(1+(1/(2*m)))
        rbr1 = (1/4)*( ( ((m+1/2)^7) * (N^2) ) / (3*(rho^(3/2))*F) ) + ((2*m+1)*(N+1)) / (sqrt(rho)*F)
        rbr2 = (1-delta)^ell
        if(rbr1 <= rbr2): 
            m_lower = m
        else: 
            m_upper = m
    
    # linear scan when interval is small enough
    m = m_lower
    delta = 1-sqrt(rho)*(1+(1/(2*m)))
    rbr1 = (1/4)*( ( ((m+1/2)^7) * (N^2) ) / (3*(rho^(3/2))*F) ) + ((2*m+1)*(N+1)) / (sqrt(rho)*F)
    rbr2 = (1-delta)^ell
    rbr_diff_prev = 0
    rbr_diff_next = abs(rbr1 - rbr2)
    while(rbr1 <= rbr2):
        m = m+1
        delta = 1-sqrt(rho)*(1+(1/(2*m)))
        rbr1 = (1/4)*( ( ((m+1/2)^7) * (N^2) ) / (3*(rho^(3/2))*F) ) + ((2*m+1)*(N+1)) / (sqrt(rho)*F)
        rbr2 = (1-delta)^ell
        rbr_diff_prev = 0
        rbr_diff_next = abs(rbr1 - rbr2)
    if(rbr_diff_prev < rbr_diff_next):
        m = m-1
    return m
    
## The following 3 functions are for calculating the tradeoffs
##  between adversarial queries Q and achievable soundness error.

## Calculation under provable RBR Soundness of FRI
##   eps = max{ (1/4) * ((m+1/2)^7 * (2^{k}/rho)^2)/ (3(rho)^(3/2)*F) + ((2*m+1)/sqrt(rho))*(((2^{k}/rho)+1)/F) , (1-delta)^ell / 2^z }
##   delta = 1-sqrt(rho)(1+1/2m)
## Parameters:
##   F = Field size
##   rho = RS code rate
##   k = log(degree bound)
##   m = parameter for johnson proximity gap, at least 3
##   lgQ_list = list containing log of adversarial query bounds
##   kappa = RO hash output length (in bits)
##   ell = number of verifier queries during FRI Query phase
##   z = # grinding bits
##   alpha = weight of RBR error
##   beta = weight of Merkle error
def provable_calcs(F, rho, k, m, lgQ_list, kappa, ell, z=0, alpha=1/2, beta=1/2): 
    N = (2^k)/rho
    n = log2(N)
    nu_list = []
    delta = 1-sqrt(rho)*(1+1/(2*m))
    rbr = max( (1/4)*(((m+1/2)^7 * N^2) / ( 3*(rho^(3/2))*F )) + ((2*m+1)/sqrt(rho))*((N+1)/F), (((1-delta)^ell)/2^z)  )
    r = k
    for i in lgQ_list:
        Q = 2^i
        nu1 = -log2( 2*(Q+r)*rbr*(1/alpha) )
        nu2 = -log2( (3.5 * Q^2) / (beta * 2^kappa) )
        nu = floor(min(nu1,nu2))
        if(nu >= 0):
            nu_list.append( (i, nu) )
        proof_len = proof_size(kappa, ell, k, log2(N), F)
        print("$Q=2^{",i,"}$,","({}, {}, {}, {})".format(nu, RR(delta).str(digits=5), ell, proof_len))
    
    return nu_list

## Calculation under first conjectured RBR Soundness of FRI
##   eps = max{ (N^c2) / (((rho*eta)^(c1))*F)  , (1-delta)^ell / 2^z }
##   delta = 1-rho
## Parameters:
##   F = Field size
##   rho = RS code rate
##   k = log(degree bound)
##   m = Johnson bound >= 3 parameter for comparing with provable case
##   lgQ_list = list containing log of adversarial query bounds
##   kappa = RO hash output length (in bits)
##   ell = # verifier queries during FRI Query phase
##   z = # grinding bits
##   alpha = weight of RBR error
##   beta = weight of Merkle error
##   c1, c2 = constants >= 1
def conj_calcs_1(F, rho, k, m, lgQ_list, kappa, ell, z=0, alpha=1/2, beta=1/2, c1=1, c2=1):
    N = (2^k)/rho
    # eta = calc_eta(N, k, rho, F, ell, z=0, c1=1, c2=1)
    # print("eta = {}".format(RR(eta).str(digits=5)))
    eta = rho/(2*m)
    delta = 1-rho-eta
    rbr = max( (N^c2) / (((rho*eta)^(c1))*F) , ((1-delta)^ell / 2^z))
    nu_list = []
    r = k
    for i in lgQ_list:
        Q = 2^i
        nu1 = -log2( (Q+r)*(rbr/alpha) ) 
        nu2 = -log2( (3.5 * Q^2) / (beta * 2^kappa) )
        nu = floor(min(nu1,nu2))
        if(nu >= 0):
            nu_list.append( (i, nu) )
        proof_len = proof_size(kappa, ell, k, log2(N), F)
        print("$Q=2^{",i,"}$,","({}, {}, {}, {})".format(nu, RR(delta).str(digits=5), ell, proof_len))

    return nu_list

## Calculation under conjectured RBR Soundness of FRI
##   eps = max{ 1/F  , (1-delta)^ell / 2^z }
##   delta = 1-rho
## Parameters:
##   F = Field size
##   rho = RS code rate
##   k = log(degree bound)
##   lgQ_list = list containing log of adversarial query bounds
##   kappa = RO hash output length (in bits)
##   ell = # verifier queries during FRI Query phase
##   z = # grinding bits
##   alpha = weight of RBR error
##   beta = weight of Merkle error
def conj_calcs_2(F, rho, k, lgQ_list, kappa, ell, z=0, alpha=1/2, beta=1/2):
    delta = 1-rho
    N = (2^k)/rho
    rbr = max(1/F, ((1-delta)^ell / 2^z))
    nu_list = []
    r = k
    for i in lgQ_list:
        Q = 2^i
        nu1 = -log2( (Q+r)*(rbr/alpha) ) 
        nu2 = -log2( (3.5 * Q^2) / (beta * 2^kappa) )
        nu = floor(min(nu1,nu2))
        if(nu >= 0):
            nu_list.append( (i, nu) )
        proof_len = proof_size(kappa, ell, k, log2(N), F)
        print("$Q=2^{",i,"}$,","({}, {}, {}, {})".format(nu, RR(delta).str(digits=5), ell, proof_len))

    return nu_list


## In the next 3 functions, we calculate the bits of security
##   that are achievable certain sets of parameters.
def bits_of_security_provable(F, rho, k, m, kappa, ell, z=0, alpha=1/2, beta=1/2):
    N = (2^k)/rho
    delta = 1-sqrt(rho)*(1+1/(2*m))
    print("delta = {}".format(RR(delta).str(digits=5)))
    rbr = max( (1/4)*(((m+1/2)^7 * N^2) / ( 3*(rho^(3/2))*F )) + ((2*m+1)/sqrt(rho))*((N+1)/F), (((1-delta)^ell)/2^z)  )
    lam = floor(-log2((1/alpha)*2*rbr))
    lgQ = floor(log2( beta * (2^(kappa - lam) / 3.5) ) )
    print("Bits of security (Provable): $\\lambda \\leq {}$, $Q \\leq 2^{}$".format(lam,lgQ))
    return (lam, 0)

def bits_of_security_conj1(F, rho, k, m, kappa, ell, z=0, alpha=1/2, beta=1/2, c1=1, c2=1):
    N = (2^k)/rho
    # eta = calc_eta(N, k, rho, F, ell, z=0, c1=1, c2=1)
    eta = rho/(2*m)
    delta = 1-rho-eta
    print("delta = {}".format(RR(delta).str(digits=5)))
    rbr = max( (N^c2) / (((rho*eta)^(c1))*F), ((1-delta)^ell) / 2^z)
    lam = floor(-log2((1/alpha)*2*rbr))
    lgQ = floor(log2( beta * (2^(kappa - lam) / 3.5) ) )
    print("Bits of security (Conjecture 1): $\\lambda \\leq {}$, $Q \\leq 2^{}$".format(lam, lgQ))
    return (lam, 0)

def bits_of_security_conj2(F, rho, k, kappa, ell, z=0, alpha=1/2, beta=1/2):
    delta = 1-rho
    N = (2^k)/rho
    rbr = max( 1/F, ((1-delta)^ell) / 2^z)
    lam = floor(-log2((1/alpha)*2*rbr))
    lgQ = floor(log2( beta * (2^(kappa - lam) / 3.5) ) )
    print("Bits of security (Conjecture 2): $\\lambda \\leq {}$, $Q \\leq 2^{}$".format(lam, lgQ))
    return (lam, 0)

## The following function calculates ell such that
## the query phase achieves lambda bits of security
## Parameters:
##   delta: proximity parameter
##   z: grinding bits
##   lam: target bits of security
def ell_calc(delta, z, lam):
    return ceil( (lam + 1 - z) / log2(1/(1-delta)) )



### Function to run above calculations of a system ###
def run_calcs(name, lgQ_list, kappa, F, rho, k, ell_list, z=0):
    print()
    print("=== {} ===".format(name))
    
    print("Provable Security Calculations")

    nu_list = []
    N = (2^k)/rho
    ell = ell_list[0]
    m = calc_max_nu_m(N, k, rho, F, ell, z)
    print("m = {}".format(m))
    nu_list = provable_calcs(F, rho, k, m, lgQ_list, kappa, ell, z)
    nu_list.append(bits_of_security_provable(F, rho, k, m, kappa, ell, z))

    list_plot(nu_list, True, marker="s").show()

    # If there is grinding, show what would have happened WITHOUT grinding
    if(z>0): 
        print("-- without grinding --")
        nu_list = provable_calcs(F, rho, k, m, lgQ_list, kappa, ell_list[0])
        nu_list.append(bits_of_security_provable(F, rho, k, m, kappa, ell))
        list_plot(nu_list, True, marker="s").show()
        
    print()
    print("Conjectured Security Calculations 1")
    if(len(ell_list)> 1):
        ell = ell_list[1]
    nu_list = conj_calcs_1(F, rho, k, m, lgQ_list, kappa, ell, z)
    nu_list.append(bits_of_security_conj1(F, rho, k, m, kappa, ell, z))

    list_plot(nu_list, True, marker="s").show()

    # If there is grinding, show what would have happened WITHOUT grinding
    if(z>0): 
        print("-- without grinding -- ")
        nu_list = conj_calcs_1(F, rho, k, m, lgQ_list, kappa, ell)
        nu_list.append(bits_of_security_conj1(F, rho, k, m, kappa, ell))
        list_plot(nu_list, True, marker="s").show()

    print()
    print("Conjectured Security Calculations 2")
    if(len(ell_list)> 1):
        ell = ell_list[2]
    nu_list = conj_calcs_2(F, rho, k, lgQ_list, kappa, ell, z)
    nu_list.append(bits_of_security_conj2(F, rho, k, kappa, ell, z))

    list_plot(nu_list, True, marker="s").show()

    # If there is grinding, show what would have happened WITHOUT grinding
    if(z>0): 
        print("-- without grinding -- ")
        nu_list = conj_calcs_2(F, rho, k, lgQ_list, kappa, ell)
        nu_list.append(bits_of_security_conj2(F, rho, k, kappa, ell))
        list_plot(nu_list, True, marker="s").show()
    
    print()
    print("+=+=+=+=+=+=+=+=+=+=+=+=+")


    

### set targets for number of RO queries ###
lgQ_list = [20*i for i in range(1,7)]

# hash output of RO
kappa = 256

    
### calculations for RISC Zero Parameters ###

# RISC Zero: 1
name = "RISC Zero Parameters: 1"
F = (2^64 -2^32+1)^2 # goldilocks field deg 2 ext; https://github.com/risc0/risc0/blob/a65a841874c0cb27692bd4f7b95d0fcf1e5a46a1/risc0/core/src/field/goldilocks.rs
rho = 1/4
k = 24
ell = [50]

# run_calcs(name, [35,40,60,80], kappa, F, rho, k, ell)
run_calcs(name, lgQ_list, kappa, F, rho, k, ell)

# RISC Zero: 2
name = "RISC Zero Parameters: 2"
F = (15 * 2^27 + 1)^4 # baby bear deg 4 ext; https://github.com/risc0/risc0/blob/a65a841874c0cb27692bd4f7b95d0fcf1e5a46a1/risc0/core/src/field/baby_bear.rs
rho = 1/4
k = 24
ell = [50]

# run_calcs(name, [35,40,60,80], kappa, F, rho, k, ell)
run_calcs(name, lgQ_list, kappa, F, rho, k, ell)

### calculations for Plonky2 Parameters, Part 1 ###
name ="Plonky2 Parameters 1"
F = (2^64 - 2^32 + 1)^2 # goldilocks field deg 2 ext
rho = 1/2
k = 31
ell = [84]
z=16

# run_calcs(name, [40,50,60,80], kappa, F, rho, k, ell, z)
run_calcs(name, lgQ_list, kappa, F, rho, k, ell)

    

### calculations for Plonky2 Parameters, Part 2 ###
name = "Plonky2 Parameters 2"
F = (2^64 - 2^32 + 1)^2
rho = 1/8
k = 29
ell = [28]
z=16

# run_calcs(name, [40,50,60,80], kappa, F, rho, k, ell, z)
run_calcs(name, lgQ_list, kappa, F, rho, k, ell)


### calculations for lambdaworks parameters ###
F = 2^(251) + 17*2^(192) + 1 # https://starkware.co/resource/moving-from-solidity-to-cairo/
rho = 1/4
k = log2((2^(40)) * rho)
z=20
ell = [80, 31, 31]

name = "lambdaworks Parameters: 80-bits" 
# run_calcs(name, [50,60,70,80], kappa, F, rho, k, ell, z)
run_calcs(name, lgQ_list, kappa, F, rho, k, ell)

name="lambdaworks Paramegers: 100-bits"
ell=[104, 41, 41]
# run_calcs(name, [50,60,70,80], kappa, F, rho, k, ell, z)
run_calcs(name, lgQ_list, kappa, F, rho, k, ell)

name = "lambdaworks Parameters: 128-bits"
ell=[140, 55, 55]
# run_calcs(name, [50,60,70,80], kappa, F, rho, k, ell, z)
run_calcs(name, lgQ_list, kappa, F, rho, k, ell)



### calculations for Stone Prover Parameters ###

name = "Stone Prover Parameters: k=13"
F = 2^(251) + 17*2^(192) + 1
rho = 1/16
k = 13
ell = [18]
z=24
# run_calcs(name, [30,40,60,80], kappa, F, rho, k, ell, z)
run_calcs(name, lgQ_list, kappa, F, rho, k, ell)

name = "Stone Prover Parameters: k=30"
k = 30
# run_calcs(name, [45,50,60,80], kappa, F, rho, k, ell, z)
run_calcs(name, lgQ_list, kappa, F, rho, k, ell)


### dYdX calculations ###
name = "dYdX Parameters"
F = 2^(251) + 17*2^(192) + 1
k = 31
z = 32
ell = [12]
rho=1/16
# run_calcs(name, [45,50,60,80], kappa, F, rho, k, ell, z)
run_calcs(name, lgQ_list, kappa, F, rho, k, ell)

### miden-vm ###
name = "miden-vm: 96-bits"
F = (2^(64)-2^(32)+1)^2
ell = [27]
z=16
rho=1/8
k = 30
# run_calcs(name, [45,50,60,80], kappa, F, rho, k, ell, z)
run_calcs(name, lgQ_list, kappa, F, rho, k, ell)

name="miden-vm: 128-bits"
F= (2^(64)-2^(32)+1)^3
z=21
rho=1/16
# run_calcs(name, [45,50,60,80], kappa, F, rho, k, ell, z)
run_calcs(name, lgQ_list, kappa, F, rho, k, ell)

### boojam default/benchmark parameters ###
name = "boojam: default parameters"
F = (2^(64)-2^(32)+1)^2
z=20
rho=1/4
ell=[40]
k = 19
# run_calcs(name, [30,40,60,80], kappa, F, rho, k, ell, z)
run_calcs(name, lgQ_list, kappa, F, rho, k, ell)

name = "boojam: benchmark parameters"
rho = 1/8
ell=[34]
# run_calcs(name, [30,40,60,80], kappa, F, rho, k, ell)
run_calcs(name, lgQ_list, kappa, F, rho, k, ell)

### SHARP Verifier parameters ###
name = "SHARP Verifier"
F = 2^(251) + 17*2^(192) + 1
rho = 1/32
ell = [13]
k = 26
z = 31
# run_calcs(name, [40,50,60,80], kappa, F, rho, k, ell, z)
run_calcs(name, lgQ_list, kappa, F, rho, k, ell)
# Out:
# === RISC Zero Parameters: 1 ===
# Provable Security Calculations
# m = 16
# $Q=2^{ 20 }$, (25, 0.48438, 50, 1.17 MiB)
# $Q=2^{ 40 }$, (5, 0.48438, 50, 1.17 MiB)
# $Q=2^{ 60 }$, (-15, 0.48438, 50, 1.17 MiB)
# $Q=2^{ 80 }$, (-35, 0.48438, 50, 1.17 MiB)
# $Q=2^{ 100 }$, (-55, 0.48438, 50, 1.17 MiB)
# $Q=2^{ 120 }$, (-75, 0.48438, 50, 1.17 MiB)
# delta = 0.48438
# Bits of security (Provable): $\lambda \leq 45$, $Q \leq 2^208$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 1
# $Q=2^{ 20 }$, (71, 0.74219, 50, 1.17 MiB)
# $Q=2^{ 40 }$, (51, 0.74219, 50, 1.17 MiB)
# $Q=2^{ 60 }$, (31, 0.74219, 50, 1.17 MiB)
# $Q=2^{ 80 }$, (11, 0.74219, 50, 1.17 MiB)
# $Q=2^{ 100 }$, (-9, 0.74219, 50, 1.17 MiB)
# $Q=2^{ 120 }$, (-29, 0.74219, 50, 1.17 MiB)
# delta = 0.74219
# Bits of security (Conjecture 1): $\lambda \leq 90$, $Q \leq 2^163$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 2
# $Q=2^{ 20 }$, (78, 0.75000, 50, 1.17 MiB)
# $Q=2^{ 40 }$, (58, 0.75000, 50, 1.17 MiB)
# $Q=2^{ 60 }$, (38, 0.75000, 50, 1.17 MiB)
# $Q=2^{ 80 }$, (18, 0.75000, 50, 1.17 MiB)
# $Q=2^{ 100 }$, (-2, 0.75000, 50, 1.17 MiB)
# $Q=2^{ 120 }$, (-22, 0.75000, 50, 1.17 MiB)
# Bits of security (Conjecture 2): $\lambda \leq 98$, $Q \leq 2^155$
# Graphics object consisting of 1 graphics primitive
# +=+=+=+=+=+=+=+=+=+=+=+=+
#
# === RISC Zero Parameters: 2 ===
# Provable Security Calculations
# m = 11
# $Q=2^{ 20 }$, (24, 0.47727, 50, 1.17 MiB)
# $Q=2^{ 40 }$, (4, 0.47727, 50, 1.17 MiB)
# $Q=2^{ 60 }$, (-16, 0.47727, 50, 1.17 MiB)
# $Q=2^{ 80 }$, (-36, 0.47727, 50, 1.17 MiB)
# $Q=2^{ 100 }$, (-56, 0.47727, 50, 1.17 MiB)
# $Q=2^{ 120 }$, (-76, 0.47727, 50, 1.17 MiB)
# delta = 0.47727
# Bits of security (Provable): $\lambda \leq 44$, $Q \leq 2^209$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 1
# $Q=2^{ 20 }$, (68, 0.73864, 50, 1.17 MiB)
# $Q=2^{ 40 }$, (48, 0.73864, 50, 1.17 MiB)
# $Q=2^{ 60 }$, (28, 0.73864, 50, 1.17 MiB)
# $Q=2^{ 80 }$, (8, 0.73864, 50, 1.17 MiB)
# $Q=2^{ 100 }$, (-12, 0.73864, 50, 1.17 MiB)
# $Q=2^{ 120 }$, (-32, 0.73864, 50, 1.17 MiB)
# delta = 0.73864
# Bits of security (Conjecture 1): $\lambda \leq 87$, $Q \leq 2^166$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 2
# $Q=2^{ 20 }$, (78, 0.75000, 50, 1.17 MiB)
# $Q=2^{ 40 }$, (58, 0.75000, 50, 1.17 MiB)
# $Q=2^{ 60 }$, (38, 0.75000, 50, 1.17 MiB)
# $Q=2^{ 80 }$, (18, 0.75000, 50, 1.17 MiB)
# $Q=2^{ 100 }$, (-2, 0.75000, 50, 1.17 MiB)
# $Q=2^{ 120 }$, (-22, 0.75000, 50, 1.17 MiB)
# Bits of security (Conjecture 2): $\lambda \leq 98$, $Q \leq 2^155$
# Graphics object consisting of 1 graphics primitive
# +=+=+=+=+=+=+=+=+=+=+=+=+
#
# === Plonky2 Parameters 1 ===
# Provable Security Calculations
# m = 15
# $Q=2^{ 20 }$, (16, 0.26932, 84, 2.94 MiB)
# $Q=2^{ 40 }$, (-4, 0.26932, 84, 2.94 MiB)
# $Q=2^{ 60 }$, (-24, 0.26932, 84, 2.94 MiB)
# $Q=2^{ 80 }$, (-44, 0.26932, 84, 2.94 MiB)
# $Q=2^{ 100 }$, (-64, 0.26932, 84, 2.94 MiB)
# $Q=2^{ 120 }$, (-84, 0.26932, 84, 2.94 MiB)
# delta = 0.26932
# Bits of security (Provable): $\lambda \leq 36$, $Q \leq 2^217$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 1
# $Q=2^{ 20 }$, (59, 0.48333, 84, 2.94 MiB)
# $Q=2^{ 40 }$, (39, 0.48333, 84, 2.94 MiB)
# $Q=2^{ 60 }$, (19, 0.48333, 84, 2.94 MiB)
# $Q=2^{ 80 }$, (-1, 0.48333, 84, 2.94 MiB)
# $Q=2^{ 100 }$, (-21, 0.48333, 84, 2.94 MiB)
# $Q=2^{ 120 }$, (-41, 0.48333, 84, 2.94 MiB)
# delta = 0.48333
# Bits of security (Conjecture 1): $\lambda \leq 78$, $Q \leq 2^175$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 2
# $Q=2^{ 20 }$, (62, 0.50000, 84, 2.94 MiB)
# $Q=2^{ 40 }$, (42, 0.50000, 84, 2.94 MiB)
# $Q=2^{ 60 }$, (22, 0.50000, 84, 2.94 MiB)
# $Q=2^{ 80 }$, (2, 0.50000, 84, 2.94 MiB)
# $Q=2^{ 100 }$, (-18, 0.50000, 84, 2.94 MiB)
# $Q=2^{ 120 }$, (-38, 0.50000, 84, 2.94 MiB)
# Bits of security (Conjecture 2): $\lambda \leq 82$, $Q \leq 2^171$
# Graphics object consisting of 1 graphics primitive
# +=+=+=+=+=+=+=+=+=+=+=+=+
#
# === Plonky2 Parameters 2 ===
# Provable Security Calculations
# m = 9
# $Q=2^{ 20 }$, (17, 0.62680, 28, 990 KiB)
# $Q=2^{ 40 }$, (-3, 0.62680, 28, 990 KiB)
# $Q=2^{ 60 }$, (-23, 0.62680, 28, 990 KiB)
# $Q=2^{ 80 }$, (-43, 0.62680, 28, 990 KiB)
# $Q=2^{ 100 }$, (-63, 0.62680, 28, 990 KiB)
# $Q=2^{ 120 }$, (-83, 0.62680, 28, 990 KiB)
# delta = 0.62680
# Bits of security (Provable): $\lambda \leq 37$, $Q \leq 2^216$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 1
# $Q=2^{ 20 }$, (60, 0.86806, 28, 990 KiB)
# $Q=2^{ 40 }$, (40, 0.86806, 28, 990 KiB)
# $Q=2^{ 60 }$, (20, 0.86806, 28, 990 KiB)
# $Q=2^{ 80 }$, (0, 0.86806, 28, 990 KiB)
# $Q=2^{ 100 }$, (-20, 0.86806, 28, 990 KiB)
# $Q=2^{ 120 }$, (-40, 0.86806, 28, 990 KiB)
# delta = 0.86806
# Bits of security (Conjecture 1): $\lambda \leq 79$, $Q \leq 2^174$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 2
# $Q=2^{ 20 }$, (62, 0.87500, 28, 990 KiB)
# $Q=2^{ 40 }$, (42, 0.87500, 28, 990 KiB)
# $Q=2^{ 60 }$, (22, 0.87500, 28, 990 KiB)
# $Q=2^{ 80 }$, (2, 0.87500, 28, 990 KiB)
# $Q=2^{ 100 }$, (-18, 0.87500, 28, 990 KiB)
# $Q=2^{ 120 }$, (-38, 0.87500, 28, 990 KiB)
# Bits of security (Conjecture 2): $\lambda \leq 82$, $Q \leq 2^171$
# Graphics object consisting of 1 graphics primitive
# +=+=+=+=+=+=+=+=+=+=+=+=+
#
# === lambdaworks Parameters: 80-bits ===
# Provable Security Calculations
# m = 8685
# $Q=2^{ 20 }$, (57, 0.49997, 80, 4.36 MiB)
# $Q=2^{ 40 }$, (37, 0.49997, 80, 4.36 MiB)
# $Q=2^{ 60 }$, (17, 0.49997, 80, 4.36 MiB)
# $Q=2^{ 80 }$, (-3, 0.49997, 80, 4.36 MiB)
# $Q=2^{ 100 }$, (-23, 0.49997, 80, 4.36 MiB)
# $Q=2^{ 120 }$, (-43, 0.49997, 80, 4.36 MiB)
# delta = 0.49997
# Bits of security (Provable): $\lambda \leq 77$, $Q \leq 2^176$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 1
# $Q=2^{ 20 }$, (40, 0.74999, 31, 1.69 MiB)
# $Q=2^{ 40 }$, (20, 0.74999, 31, 1.69 MiB)
# $Q=2^{ 60 }$, (0, 0.74999, 31, 1.69 MiB)
# $Q=2^{ 80 }$, (-20, 0.74999, 31, 1.69 MiB)
# $Q=2^{ 100 }$, (-40, 0.74999, 31, 1.69 MiB)
# $Q=2^{ 120 }$, (-60, 0.74999, 31, 1.69 MiB)
# delta = 0.74999
# Bits of security (Conjecture 1): $\lambda \leq 59$, $Q \leq 2^194$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 2
# $Q=2^{ 20 }$, (40, 0.75000, 31, 1.69 MiB)
# $Q=2^{ 40 }$, (20, 0.75000, 31, 1.69 MiB)
# $Q=2^{ 60 }$, (0, 0.75000, 31, 1.69 MiB)
# $Q=2^{ 80 }$, (-20, 0.75000, 31, 1.69 MiB)
# $Q=2^{ 100 }$, (-40, 0.75000, 31, 1.69 MiB)
# $Q=2^{ 120 }$, (-60, 0.75000, 31, 1.69 MiB)
# Bits of security (Conjecture 2): $\lambda \leq 60$, $Q \leq 2^193$
# Graphics object consisting of 1 graphics primitive
# +=+=+=+=+=+=+=+=+=+=+=+=+
#
# === lambdaworks Paramegers: 100-bits ===
# Provable Security Calculations
# m = 813
# $Q=2^{ 20 }$, (81, 0.49969, 104, 5.67 MiB)
# $Q=2^{ 40 }$, (61, 0.49969, 104, 5.67 MiB)
# $Q=2^{ 60 }$, (41, 0.49969, 104, 5.67 MiB)
# $Q=2^{ 80 }$, (21, 0.49969, 104, 5.67 MiB)
# $Q=2^{ 100 }$, (1, 0.49969, 104, 5.67 MiB)
# $Q=2^{ 120 }$, (-19, 0.49969, 104, 5.67 MiB)
# delta = 0.49969
# Bits of security (Provable): $\lambda \leq 101$, $Q \leq 2^152$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 1
# $Q=2^{ 20 }$, (60, 0.74985, 41, 2.23 MiB)
# $Q=2^{ 40 }$, (40, 0.74985, 41, 2.23 MiB)
# $Q=2^{ 60 }$, (20, 0.74985, 41, 2.23 MiB)
# $Q=2^{ 80 }$, (0, 0.74985, 41, 2.23 MiB)
# $Q=2^{ 100 }$, (-20, 0.74985, 41, 2.23 MiB)
# $Q=2^{ 120 }$, (-40, 0.74985, 41, 2.23 MiB)
# delta = 0.74985
# Bits of security (Conjecture 1): $\lambda \leq 79$, $Q \leq 2^174$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 2
# $Q=2^{ 20 }$, (60, 0.75000, 41, 2.23 MiB)
# $Q=2^{ 40 }$, (40, 0.75000, 41, 2.23 MiB)
# $Q=2^{ 60 }$, (20, 0.75000, 41, 2.23 MiB)
# $Q=2^{ 80 }$, (0, 0.75000, 41, 2.23 MiB)
# $Q=2^{ 100 }$, (-20, 0.75000, 41, 2.23 MiB)
# $Q=2^{ 120 }$, (-40, 0.75000, 41, 2.23 MiB)
# Bits of security (Conjecture 2): $\lambda \leq 80$, $Q \leq 2^173$
# Graphics object consisting of 1 graphics primitive
# +=+=+=+=+=+=+=+=+=+=+=+=+
#
# === lambdaworks Parameters: 128-bits ===
# Provable Security Calculations
# m = 30
# $Q=2^{ 20 }$, (114, 0.49167, 140, 7.63 MiB)
# $Q=2^{ 40 }$, (94, 0.49167, 140, 7.63 MiB)
# $Q=2^{ 60 }$, (74, 0.49167, 140, 7.63 MiB)
# $Q=2^{ 80 }$, (54, 0.49167, 140, 7.63 MiB)
# $Q=2^{ 100 }$, (34, 0.49167, 140, 7.63 MiB)
# $Q=2^{ 120 }$, (13, 0.49167, 140, 7.63 MiB)
# delta = 0.49167
# Bits of security (Provable): $\lambda \leq 134$, $Q \leq 2^119$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 1
# $Q=2^{ 20 }$, (87, 0.74583, 55, 3.00 MiB)
# $Q=2^{ 40 }$, (67, 0.74583, 55, 3.00 MiB)
# $Q=2^{ 60 }$, (47, 0.74583, 55, 3.00 MiB)
# $Q=2^{ 80 }$, (27, 0.74583, 55, 3.00 MiB)
# $Q=2^{ 100 }$, (7, 0.74583, 55, 3.00 MiB)
# $Q=2^{ 120 }$, (-13, 0.74583, 55, 3.00 MiB)
# delta = 0.74583
# Bits of security (Conjecture 1): $\lambda \leq 106$, $Q \leq 2^147$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 2
# $Q=2^{ 20 }$, (88, 0.75000, 55, 3.00 MiB)
# $Q=2^{ 40 }$, (68, 0.75000, 55, 3.00 MiB)
# $Q=2^{ 60 }$, (48, 0.75000, 55, 3.00 MiB)
# $Q=2^{ 80 }$, (28, 0.75000, 55, 3.00 MiB)
# $Q=2^{ 100 }$, (8, 0.75000, 55, 3.00 MiB)
# $Q=2^{ 120 }$, (-12, 0.75000, 55, 3.00 MiB)
# Bits of security (Conjecture 2): $\lambda \leq 108$, $Q \leq 2^145$
# Graphics object consisting of 1 graphics primitive
# +=+=+=+=+=+=+=+=+=+=+=+=+
#
# === Stone Prover Parameters: k=13 ===
# Provable Security Calculations
# m = 47854044
# $Q=2^{ 20 }$, (13, 0.75000, 18, 190 KiB)
# $Q=2^{ 40 }$, (-7, 0.75000, 18, 190 KiB)
# $Q=2^{ 60 }$, (-27, 0.75000, 18, 190 KiB)
# $Q=2^{ 80 }$, (-47, 0.75000, 18, 190 KiB)
# $Q=2^{ 100 }$, (-67, 0.75000, 18, 190 KiB)
# $Q=2^{ 120 }$, (-87, 0.75000, 18, 190 KiB)
# delta = 0.75000
# Bits of security (Provable): $\lambda \leq 33$, $Q \leq 2^220$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 1
# $Q=2^{ 20 }$, (50, 0.93750, 18, 190 KiB)
# $Q=2^{ 40 }$, (30, 0.93750, 18, 190 KiB)
# $Q=2^{ 60 }$, (10, 0.93750, 18, 190 KiB)
# $Q=2^{ 80 }$, (-10, 0.93750, 18, 190 KiB)
# $Q=2^{ 100 }$, (-30, 0.93750, 18, 190 KiB)
# $Q=2^{ 120 }$, (-50, 0.93750, 18, 190 KiB)
# delta = 0.93750
# Bits of security (Conjecture 1): $\lambda \leq 69$, $Q \leq 2^184$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 2
# $Q=2^{ 20 }$, (50, 0.93750, 18, 190 KiB)
# $Q=2^{ 40 }$, (30, 0.93750, 18, 190 KiB)
# $Q=2^{ 60 }$, (10, 0.93750, 18, 190 KiB)
# $Q=2^{ 80 }$, (-10, 0.93750, 18, 190 KiB)
# $Q=2^{ 100 }$, (-30, 0.93750, 18, 190 KiB)
# $Q=2^{ 120 }$, (-50, 0.93750, 18, 190 KiB)
# Bits of security (Conjecture 2): $\lambda \leq 70$, $Q \leq 2^183$
# Graphics object consisting of 1 graphics primitive
# +=+=+=+=+=+=+=+=+=+=+=+=+
#
# === Stone Prover Parameters: k=30 ===
# Provable Security Calculations
# m = 1651099
# $Q=2^{ 20 }$, (13, 0.75000, 18, 726 KiB)
# $Q=2^{ 40 }$, (-7, 0.75000, 18, 726 KiB)
# $Q=2^{ 60 }$, (-27, 0.75000, 18, 726 KiB)
# $Q=2^{ 80 }$, (-47, 0.75000, 18, 726 KiB)
# $Q=2^{ 100 }$, (-67, 0.75000, 18, 726 KiB)
# $Q=2^{ 120 }$, (-87, 0.75000, 18, 726 KiB)
# delta = 0.75000
# Bits of security (Provable): $\lambda \leq 33$, $Q \leq 2^220$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 1
# $Q=2^{ 20 }$, (50, 0.93750, 18, 726 KiB)
# $Q=2^{ 40 }$, (30, 0.93750, 18, 726 KiB)
# $Q=2^{ 60 }$, (10, 0.93750, 18, 726 KiB)
# $Q=2^{ 80 }$, (-10, 0.93750, 18, 726 KiB)
# $Q=2^{ 100 }$, (-30, 0.93750, 18, 726 KiB)
# $Q=2^{ 120 }$, (-50, 0.93750, 18, 726 KiB)
# delta = 0.93750
# Bits of security (Conjecture 1): $\lambda \leq 69$, $Q \leq 2^184$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 2
# $Q=2^{ 20 }$, (50, 0.93750, 18, 726 KiB)
# $Q=2^{ 40 }$, (30, 0.93750, 18, 726 KiB)
# $Q=2^{ 60 }$, (10, 0.93750, 18, 726 KiB)
# $Q=2^{ 80 }$, (-10, 0.93750, 18, 726 KiB)
# $Q=2^{ 100 }$, (-30, 0.93750, 18, 726 KiB)
# $Q=2^{ 120 }$, (-50, 0.93750, 18, 726 KiB)
# Bits of security (Conjecture 2): $\lambda \leq 70$, $Q \leq 2^183$
# Graphics object consisting of 1 graphics primitive
# +=+=+=+=+=+=+=+=+=+=+=+=+
#
# === dYdX Parameters ===
# Provable Security Calculations
# m = 4444427
# $Q=2^{ 20 }$, (1, 0.75000, 12, 512 KiB)
# $Q=2^{ 40 }$, (-19, 0.75000, 12, 512 KiB)
# $Q=2^{ 60 }$, (-39, 0.75000, 12, 512 KiB)
# $Q=2^{ 80 }$, (-59, 0.75000, 12, 512 KiB)
# $Q=2^{ 100 }$, (-79, 0.75000, 12, 512 KiB)
# $Q=2^{ 120 }$, (-99, 0.75000, 12, 512 KiB)
# delta = 0.75000
# Bits of security (Provable): $\lambda \leq 21$, $Q \leq 2^232$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 1
# $Q=2^{ 20 }$, (26, 0.93750, 12, 512 KiB)
# $Q=2^{ 40 }$, (6, 0.93750, 12, 512 KiB)
# $Q=2^{ 60 }$, (-14, 0.93750, 12, 512 KiB)
# $Q=2^{ 80 }$, (-34, 0.93750, 12, 512 KiB)
# $Q=2^{ 100 }$, (-54, 0.93750, 12, 512 KiB)
# $Q=2^{ 120 }$, (-74, 0.93750, 12, 512 KiB)
# delta = 0.93750
# Bits of security (Conjecture 1): $\lambda \leq 45$, $Q \leq 2^208$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 2
# $Q=2^{ 20 }$, (26, 0.93750, 12, 512 KiB)
# $Q=2^{ 40 }$, (6, 0.93750, 12, 512 KiB)
# $Q=2^{ 60 }$, (-14, 0.93750, 12, 512 KiB)
# $Q=2^{ 80 }$, (-34, 0.93750, 12, 512 KiB)
# $Q=2^{ 100 }$, (-54, 0.93750, 12, 512 KiB)
# $Q=2^{ 120 }$, (-74, 0.93750, 12, 512 KiB)
# Bits of security (Conjecture 2): $\lambda \leq 46$, $Q \leq 2^207$
# Graphics object consisting of 1 graphics primitive
# +=+=+=+=+=+=+=+=+=+=+=+=+
#
# === miden-vm: 96-bits ===
# Provable Security Calculations
# m = 8
# $Q=2^{ 20 }$, (16, 0.62435, 27, 1013 KiB)
# $Q=2^{ 40 }$, (-4, 0.62435, 27, 1013 KiB)
# $Q=2^{ 60 }$, (-24, 0.62435, 27, 1013 KiB)
# $Q=2^{ 80 }$, (-44, 0.62435, 27, 1013 KiB)
# $Q=2^{ 100 }$, (-64, 0.62435, 27, 1013 KiB)
# $Q=2^{ 120 }$, (-84, 0.62435, 27, 1013 KiB)
# delta = 0.62435
# Bits of security (Provable): $\lambda \leq 36$, $Q \leq 2^217$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 1
# $Q=2^{ 20 }$, (57, 0.86719, 27, 1013 KiB)
# $Q=2^{ 40 }$, (37, 0.86719, 27, 1013 KiB)
# $Q=2^{ 60 }$, (17, 0.86719, 27, 1013 KiB)
# $Q=2^{ 80 }$, (-3, 0.86719, 27, 1013 KiB)
# $Q=2^{ 100 }$, (-23, 0.86719, 27, 1013 KiB)
# $Q=2^{ 120 }$, (-43, 0.86719, 27, 1013 KiB)
# delta = 0.86719
# Bits of security (Conjecture 1): $\lambda \leq 76$, $Q \leq 2^177$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 2
# $Q=2^{ 20 }$, (59, 0.87500, 27, 1013 KiB)
# $Q=2^{ 40 }$, (39, 0.87500, 27, 1013 KiB)
# $Q=2^{ 60 }$, (19, 0.87500, 27, 1013 KiB)
# $Q=2^{ 80 }$, (-1, 0.87500, 27, 1013 KiB)
# $Q=2^{ 100 }$, (-21, 0.87500, 27, 1013 KiB)
# $Q=2^{ 120 }$, (-41, 0.87500, 27, 1013 KiB)
# Bits of security (Conjecture 2): $\lambda \leq 79$, $Q \leq 2^174$
# Graphics object consisting of 1 graphics primitive
# +=+=+=+=+=+=+=+=+=+=+=+=+
#
# === miden-vm: 128-bits ===
# Provable Security Calculations
# m = 807
# $Q=2^{ 20 }$, (31, 0.74985, 27, 1.05 MiB)
# $Q=2^{ 40 }$, (11, 0.74985, 27, 1.05 MiB)
# $Q=2^{ 60 }$, (-9, 0.74985, 27, 1.05 MiB)
# $Q=2^{ 80 }$, (-29, 0.74985, 27, 1.05 MiB)
# $Q=2^{ 100 }$, (-49, 0.74985, 27, 1.05 MiB)
# $Q=2^{ 120 }$, (-69, 0.74985, 27, 1.05 MiB)
# delta = 0.74985
# Bits of security (Provable): $\lambda \leq 51$, $Q \leq 2^202$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 1
# $Q=2^{ 20 }$, (86, 0.93746, 27, 1.05 MiB)
# $Q=2^{ 40 }$, (66, 0.93746, 27, 1.05 MiB)
# $Q=2^{ 60 }$, (46, 0.93746, 27, 1.05 MiB)
# $Q=2^{ 80 }$, (26, 0.93746, 27, 1.05 MiB)
# $Q=2^{ 100 }$, (6, 0.93746, 27, 1.05 MiB)
# $Q=2^{ 120 }$, (-14, 0.93746, 27, 1.05 MiB)
# delta = 0.93746
# Bits of security (Conjecture 1): $\lambda \leq 105$, $Q \leq 2^148$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 2
# $Q=2^{ 20 }$, (86, 0.93750, 27, 1.05 MiB)
# $Q=2^{ 40 }$, (66, 0.93750, 27, 1.05 MiB)
# $Q=2^{ 60 }$, (46, 0.93750, 27, 1.05 MiB)
# $Q=2^{ 80 }$, (26, 0.93750, 27, 1.05 MiB)
# $Q=2^{ 100 }$, (6, 0.93750, 27, 1.05 MiB)
# $Q=2^{ 120 }$, (-14, 0.93750, 27, 1.05 MiB)
# Bits of security (Conjecture 2): $\lambda \leq 106$, $Q \leq 2^147$
# Graphics object consisting of 1 graphics primitive
# +=+=+=+=+=+=+=+=+=+=+=+=+
#
# === boojam: default parameters ===
# Provable Security Calculations
# m = 103
# $Q=2^{ 20 }$, (17, 0.49757, 40, 641 KiB)
# $Q=2^{ 40 }$, (-3, 0.49757, 40, 641 KiB)
# $Q=2^{ 60 }$, (-23, 0.49757, 40, 641 KiB)
# $Q=2^{ 80 }$, (-43, 0.49757, 40, 641 KiB)
# $Q=2^{ 100 }$, (-63, 0.49757, 40, 641 KiB)
# $Q=2^{ 120 }$, (-83, 0.49757, 40, 641 KiB)
# delta = 0.49757
# Bits of security (Provable): $\lambda \leq 37$, $Q \leq 2^216$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 1
# $Q=2^{ 20 }$, (58, 0.74879, 40, 641 KiB)
# $Q=2^{ 40 }$, (38, 0.74879, 40, 641 KiB)
# $Q=2^{ 60 }$, (18, 0.74879, 40, 641 KiB)
# $Q=2^{ 80 }$, (-2, 0.74879, 40, 641 KiB)
# $Q=2^{ 100 }$, (-22, 0.74879, 40, 641 KiB)
# $Q=2^{ 120 }$, (-42, 0.74879, 40, 641 KiB)
# delta = 0.74879
# Bits of security (Conjecture 1): $\lambda \leq 77$, $Q \leq 2^176$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 2
# $Q=2^{ 20 }$, (58, 0.75000, 40, 641 KiB)
# $Q=2^{ 40 }$, (38, 0.75000, 40, 641 KiB)
# $Q=2^{ 60 }$, (18, 0.75000, 40, 641 KiB)
# $Q=2^{ 80 }$, (-2, 0.75000, 40, 641 KiB)
# $Q=2^{ 100 }$, (-22, 0.75000, 40, 641 KiB)
# $Q=2^{ 120 }$, (-42, 0.75000, 40, 641 KiB)
# Bits of security (Conjecture 2): $\lambda \leq 78$, $Q \leq 2^175$
# Graphics object consisting of 1 graphics primitive
# +=+=+=+=+=+=+=+=+=+=+=+=+
#
# === boojam: benchmark parameters ===
# Provable Security Calculations
# m = 25
# $Q=2^{ 20 }$, (28, 0.63938, 34, 586 KiB)
# $Q=2^{ 40 }$, (8, 0.63938, 34, 586 KiB)
# $Q=2^{ 60 }$, (-12, 0.63938, 34, 586 KiB)
# $Q=2^{ 80 }$, (-32, 0.63938, 34, 586 KiB)
# $Q=2^{ 100 }$, (-52, 0.63938, 34, 586 KiB)
# $Q=2^{ 120 }$, (-72, 0.63938, 34, 586 KiB)
# delta = 0.63938
# Bits of security (Provable): $\lambda \leq 48$, $Q \leq 2^205$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 1
# $Q=2^{ 20 }$, (73, 0.87250, 34, 586 KiB)
# $Q=2^{ 40 }$, (53, 0.87250, 34, 586 KiB)
# $Q=2^{ 60 }$, (33, 0.87250, 34, 586 KiB)
# $Q=2^{ 80 }$, (13, 0.87250, 34, 586 KiB)
# $Q=2^{ 100 }$, (-7, 0.87250, 34, 586 KiB)
# $Q=2^{ 120 }$, (-27, 0.87250, 34, 586 KiB)
# delta = 0.87250
# Bits of security (Conjecture 1): $\lambda \leq 92$, $Q \leq 2^161$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 2
# $Q=2^{ 20 }$, (80, 0.87500, 34, 586 KiB)
# $Q=2^{ 40 }$, (60, 0.87500, 34, 586 KiB)
# $Q=2^{ 60 }$, (40, 0.87500, 34, 586 KiB)
# $Q=2^{ 80 }$, (20, 0.87500, 34, 586 KiB)
# $Q=2^{ 100 }$, (0, 0.87500, 34, 586 KiB)
# $Q=2^{ 120 }$, (-20, 0.87500, 34, 586 KiB)
# Bits of security (Conjecture 2): $\lambda \leq 100$, $Q \leq 2^153$
# Graphics object consisting of 1 graphics primitive
# +=+=+=+=+=+=+=+=+=+=+=+=+
#
# === SHARP Verifier ===
# Provable Security Calculations
# m = 3645921
# $Q=2^{ 20 }$, (10, 0.82322, 13, 433 KiB)
# $Q=2^{ 40 }$, (-10, 0.82322, 13, 433 KiB)
# $Q=2^{ 60 }$, (-30, 0.82322, 13, 433 KiB)
# $Q=2^{ 80 }$, (-50, 0.82322, 13, 433 KiB)
# $Q=2^{ 100 }$, (-70, 0.82322, 13, 433 KiB)
# $Q=2^{ 120 }$, (-90, 0.82322, 13, 433 KiB)
# delta = 0.82322
# Bits of security (Provable): $\lambda \leq 30$, $Q \leq 2^223$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 1
# $Q=2^{ 20 }$, (43, 0.96875, 13, 433 KiB)
# $Q=2^{ 40 }$, (23, 0.96875, 13, 433 KiB)
# $Q=2^{ 60 }$, (3, 0.96875, 13, 433 KiB)
# $Q=2^{ 80 }$, (-17, 0.96875, 13, 433 KiB)
# $Q=2^{ 100 }$, (-37, 0.96875, 13, 433 KiB)
# $Q=2^{ 120 }$, (-57, 0.96875, 13, 433 KiB)
# delta = 0.96875
# Bits of security (Conjecture 1): $\lambda \leq 62$, $Q \leq 2^191$
# Graphics object consisting of 1 graphics primitive
# Conjectured Security Calculations 2
# $Q=2^{ 20 }$, (43, 0.96875, 13, 433 KiB)
# $Q=2^{ 40 }$, (23, 0.96875, 13, 433 KiB)
# $Q=2^{ 60 }$, (3, 0.96875, 13, 433 KiB)
# $Q=2^{ 80 }$, (-17, 0.96875, 13, 433 KiB)
# $Q=2^{ 100 }$, (-37, 0.96875, 13, 433 KiB)
# $Q=2^{ 120 }$, (-57, 0.96875, 13, 433 KiB)
# Bits of security (Conjecture 2): $\lambda \leq 63$, $Q \leq 2^190$
# Graphics object consisting of 1 graphics primitive
# +=+=+=+=+=+=+=+=+=+=+=+=+

# %%
RR = RealField(1000)


def log2(x): return log(x,2)

def bits_to_bytes(x):
    byts = x/8
    KiB = 2^(10)
    MiB = 2^(20)
    GiB = 2^(30)
    TiB = 2^(40)
    if(byts < KiB):
        return "{}B".format(floor(byts))
    elif(byts < MiB):
        return "{}K".format(floor(byts/KiB))
    elif(byts < GiB):
        return "{}M".format(RR(byts/MiB).str(digits=3))
    elif(byts < TiB):
        return "{}G".format(RR(byts/GiB).str(digits=3))
    else:
        return "{}T".format(RR(byts/TiB).str(digits=3))

        

def proof_size(hash_out, ell, k, n, F):
    f_bits = (2*k*ell+1)*ceil(log2(F))
    hash_number = k + ell*( (n+1)*(n+2) - (n-k+1)*(n-k+2) )
    hash_bits = hash_out*hash_number
    
    total_bits = f_bits + hash_bits
    return(bits_to_bytes(total_bits))


def batch_proof_size(hash_out, ell, k, n, F, t):
    f_bits = (2*ell*(k+t)+1)*ceil(log2(F))
    hash_number = k + ell*( (n+1)*(n+2) - (n-k+1)*(n-k+2) ) + t*(1 + 2*ell*(n+1))
    hash_bits = hash_out * hash_number
    𝜌= 1/2 
    total_bits = f_bits + hash_bits
    return(bits_to_bytes(total_bits))

def valid_m(m, nu, N, k, Q, rho, F):
    upper = 1 / ( (Q+k)*(2^(nu+1)) )
    t1 = (1/4)*( ( ((m+1/2)^7) * (N^2) ) / (3*(rho^(3/2))*F) )
    t2 = ((2*m+1)*(N+1)) / (sqrt(rho)*F)
    m_bound = t1+t2
    return (m_bound <= upper)

def calc_max_m(nu, N, k, Q, rho, F):
    m = 3
    feasible = False
    # First, double until we find m such that m_bound(m/2) <= upper < m_bound(m)
    while(valid_m(m,nu,N,k,Q,rho,F)):
        feasible = True
        m = 2*m
    if(not feasible):
        # checks if we ran the above loop at least 1 iteration; otherwise, there is no feasible solution
        return 0

    # there is a feasible solution for some m* in the range [m/2,m]; we now do binary search to find it
    m_upper = m
    m_lower = m/2
    while(m_upper - m_lower > 200): 
        m = floor((m_upper + m_lower) / 2) # this is the midpoint
        if(valid_m(m, nu, N, k, Q, rho, F)): # if midpoint is valid, our range is [m, m_upper], so we update m_lower
            m_lower = m
        else: # otherwise if midpoint is not valid, our range is [m_lower, m]
            m_upper = m
    
    # linear scan when interval is small enough
    m = m_lower
    while(valid_m(m, nu, N, k, Q, rho, F)):
        m = m+1
    return m-1



def calc_bound_provable(nu, lgQ_list, F_list, k_list, rho_list, kappa):
    for lgQ in lgQ_list:
        Q = 2^(lgQ) # number of RO queries we're allowing an adversary to make
        hash_out = kappa # hash output length
        print("nu =", nu)
        print("\\hhline{|t:==:t|}")
        out_head = "\\multicolumn{2}{||c||}{$\\nu = " + str(nu) + "$} "
        out_head = out_head + "& \\multicolumn{4}{c}{\\cref{cor:fs-fri}} \\\\\\hhline{||~~||----}\n"
        out_head = out_head + "\\multicolumn{2}{||c||}{$Q = 2^{" +str(lgQ) + "}$} "
        for rho in rho_list:
            out_head = out_head + "& $\\rho = " + str(rho) + "$ "
        out_head = out_head + "\\\\\\hhline{|b:==:b|*{4}{=|}}"
        print(out_head)
        for F in F_list:
            #print("\tField of size 2^{f}".format(f=log(F,2)))
            out = "{} ".format(log2(F))
            out2 = ""
            for k in k_list:
                #print("\tDomain of size 2^{n}".format(n=log(N,2)))
                out2 = out2 + "& {} ".format(k)
                for rho in rho_list:
                    delta = 0 # FRI proximity parameter to calculate
                    valid = True # check if computation below has valid constraints
                    # m=0 # Johnson proximity parameter to compute
                    n=floor(log2((2^k)/rho)) # log2 size of the evaluation domain/codeword length
                    N = 2^n

                    m = calc_max_m(nu, N, k, Q, rho, F)
                    
                    # do calculations for provable levels of security
                    # m1 = floor( ( (12*(rho^(3/2))*F) /( N*(Q+k)* (2^(nu+2)) ) )^(1/7) - (1/2) )
                    # m2 = floor( (1/2)*(((F*sqrt(rho)) / ( (N+1)*(Q+k)*(2^(nu+2)) )) - 1 ) )
                    # m = min(m1,m2)
                    if(3 > m):
                        valid = False # constraint is violated
                    else:
                        delta = 1-sqrt(rho)*(1+(1/(2*m)))


                    if(valid):
                        upper = 1/((Q+k)*(2^(nu+1)))
                        ell = ceil( log2(upper) / log2(1-delta) )
                        #print(ell)
                        #print(ceil(log2(upper)/log2(1-delta)))
                        out2 = out2 + "& \\small({}, {}, {}, {}) ".format(m,RR(delta).str(digits=3),ell,proof_size(hash_out, ell, k, n, F))
                    else:
                        out2 = out2 + "& \\cellcolor{lightgray} "

                out2 = out2 + "\\\\\n"
            print(out + out2[:-1] + "\\hhline{*{6}{-}}")
        out_last = "$\\log|\\bbF|$ & $k$ & \\multicolumn{4}{c}{$(m,\\delta, \\ell, |\\pi|)$} \\\\"
        print(out_last)
        print()
    return

## calculation for [BCI+20a] parameters
def calc_bound_conj_1(nu, lgQ_list, F_list, k_list, rho_list, kappa):
    for lgQ in lgQ_list:
        Q = 2^(lgQ) # number of RO queries we're allowing an adversary to make
        hash_out = kappa # hash output length
        print("nu =", nu)
        print("\\hhline{|t:==:t|}")
        out_head = "\\multicolumn{2}{||c||}{$\\nu = " + str(nu) + "$} "
        out_head = out_head + "& \\multicolumn{4}{c}{\\cref{conj:fri-1}} \\\\\\hhline{||~~||----}\n"
        out_head = out_head + "\\multicolumn{2}{||c||}{$Q = 2^{" +str(lgQ) + "}$} "
        for rho in rho_list:
            out_head = out_head + "& $\\rho = " + str(rho) + "$ "
        out_head = out_head + "\\\\\\hhline{|b:==:b|*{4}{=|}}"
        print(out_head)
        for F in F_list:
            #print("\tField of size 2^{f}".format(f=log(F,2)))
            out = "{} ".format(log2(F))
            out2 = ""
            for k in k_list:
                #print("\tDomain of size 2^{n}".format(n=log(N,2)))
                out2 = out2 + "& {} ".format(k)
                for rho in rho_list:
                    delta = 0 # FRI proximity parameter to calculate
                    valid = True # check if computation below has valid constraints
                    eta=0 
                    n=floor(log2((2^k)/rho)) # log2 size of the evaluation domain/codeword length
                    N = 2^n
                    
                    # do calculations for conjectured levels of security
                    eta = (N*(Q+k)*(2^(nu+1))) / (rho * F)
                    if(eta <= 0 or eta >= rho):
                        valid = False # constraint is violated
                    else:
                        delta = 1-rho-eta


                    if(valid):
                        upper = 1/((Q+k)*(2^(nu+1)))
                        ell = ceil( log2(upper) / log2(1-delta) )
                        #print(ell)
                        #print(ceil(log2(upper)/log2(1-delta)))
                        out2 = out2 + "& \\small({}, {}, {}) ".format(RR(delta).str(digits=3),ell,proof_size(hash_out, ell, k, n, F))
                    else:
                        out2 = out2 + "& \\cellcolor{lightgray} "

                out2 = out2 + "\\\\\n"
            print(out + out2[:-1] + "\\hhline{*{6}{-}}")
        out_last = "$\\log|\\bbF|$ & $k$ & \\multicolumn{4}{c}{$(\\delta, \\ell, |\\pi|)$} \\\\"
        print(out_last)
        print()
    return

## calculation for ethSTARK conjectured parameters
def calc_bound_conj_2(nu, lgQ_list, F_list, k_list, rho_list, kappa):
    for lgQ in lgQ_list:
        hash_out = kappa # hash output length
        print("nu =", nu)
        print("\\hhline{|t:==:t|}")
        out_head = "\\multicolumn{2}{||c||}{$\\nu = " + str(nu) + "$} "
        out_head = out_head + "& \\multicolumn{4}{c}{\\cref{conj:fri-2}} \\\\\\hhline{||~~||----}\n"
        out_head = out_head + "\\multicolumn{2}{||c||}{$Q = 2^{" +str(lgQ) + "}$} "
        for rho in rho_list:
            out_head = out_head + "& $\\rho = " + str(rho) + "$ "
        out_head = out_head + "\\\\\\hhline{|b:==:b|*{4}{=|}}"
        print(out_head)
        for F in F_list:
            out = "{} ".format(log2(F))
            out2 = ""
            Q = 0
            for k in k_list:
                lgQ_valid = floor(log2((F/2^(nu+1)) - k))
                valid = True
                if(lgQ > lgQ_valid):
                    valid = False
                else:
                    Q = 2^(lgQ)
                out2 = out2 + "& {} ".format(k)
                for rho in rho_list:
                    delta = 1-rho # FRI proximity parameter 
                    n=floor(log2((2^k)/rho)) # log2 size of the evaluation domain/codeword length
                    N = 2^n

                    if(valid):
                        ell = ceil( log2( (1/((Q+k)*2^(nu+1))) ) / log2(rho) )
                        out2 = out2 + "& \\small({}, {}, {}) ".format(RR(delta).str(digits=3),ell,proof_size(hash_out, ell, k, n, F))
                    else:
                        out2 = out2 + "& \\cellcolor{lightgray} "

                out2 = out2 + "\\\\\n"
            print(out + out2[:-1] + "\\hhline{*{6}{-}}")
        out_last = "$\\log|\\bbF|$ & $k$ & \\multicolumn{4}{c}{$(\\delta, \\ell, |\\pi|)$} \\\\"
        print(out_last)
        print()
    return


#### PART 1 CALCULATIONS ####
# target field sizes
F_list = [2^i for i in [128, 192, 256]]

# log of message lengths
k_list = [i for i in [10, 15, 20, 25]] 

# target rates
rho_list = [1/2^i for i in [1, 2, 3, 4]] 

# target security levels
nu_list = [20,40,60,80] 

# hash output length
kappa = 256 


lgQ_list = [60, 80]
## compute bounds for provable security and print tables
print("===== Provable Security Calculations =====")
for nu in nu_list:
    Q_upper = floor( sqrt( ((2^(kappa-nu-1))/3) - 1 )) # upper bound on number of RO queries
    lgQ_upper = floor(log2(Q_upper))
    print("$2^{",str(lgQ_upper),"} \\leq Q < 2^{", str(lgQ_upper+1), "}$") # print powers of 2 range of Q_upper
    #lgQ_list = [floor(lgQ_upper/10)*10-i for i in [30,20,10,0]]
    
    # calculate bounds and print tables
    calc_bound_provable(nu, lgQ_list, F_list, k_list, rho_list, kappa)

## compute bounds for conjectured security from [BCI+20a] and print tables
print("===== Conjectured Security Calculations 1 =====")
for nu in nu_list:
    Q_upper = floor( sqrt( ((2^(kappa-nu-1))/3) - 1 )) # upper bound on number of RO queries
    lgQ_upper = floor(log2(Q_upper))
    print("$2^{",str(lgQ_upper),"} \\leq Q < 2^{", str(lgQ_upper+1), "}$") # print powers of 2 range of Q_upper
    #lgQ_list = [floor(lgQ_upper/10)*10-i for i in [30,20,10,0]]
    
    # calculate bounds and print tables
    calc_bound_conj_1(nu, lgQ_list, F_list, k_list, rho_list, kappa)

## compute bounds for conjectured security from ethSTARK and print tables
print("===== Conjectured Security Calculations 2 =====")
for nu in nu_list:
    Q_upper = floor( sqrt( ((2^(kappa-nu-1))/3) - 1 )) # upper bound on number of RO queries
    lgQ_upper = floor(log2(Q_upper))
    print("$2^{",str(lgQ_upper),"} \\leq Q < 2^{", str(lgQ_upper+1), "}$") # print powers of 2 range of Q_upper
    
    calc_bound_conj_2(nu, lgQ_list, F_list, k_list, rho_list, kappa)
# Out:
# ===== Provable Security Calculations =====
# $2^{ 116 } \leq Q < 2^{ 117 }$
# nu = 20
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 20$} & \multicolumn{4}{c}{\cref{cor:fs-fri}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{60}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \small(14, 0.268, 181, 905K) & \small(9, 0.472, 88, 495K) & \small(6, 0.617, 59, 369K) & \small(4, 0.719, 45, 309K) \\
# & 15 & \small(4, 0.205, 246, 2.37M) & \small(3, 0.417, 105, 1.11M) & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 20 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 192 & 10 & \small(8260, 0.293, 163, 840K) & \small(5841, 0.500, 82, 474K) & \small(4130, 0.646, 55, 352K) & \small(2920, 0.750, 41, 288K) \\
# & 15 & \small(3068, 0.293, 163, 1.60M) & \small(2169, 0.500, 82, 903K) & \small(1534, 0.646, 55, 657K) & \small(1084, 0.750, 41, 529K) \\
# & 20 & \small(1139, 0.293, 163, 2.64M) & \small(805, 0.500, 82, 1.43M) & \small(569, 0.646, 55, 1.02M) & \small(402, 0.750, 41, 833K) \\
# & 25 & \small(423, 0.292, 163, 3.92M) & \small(299, 0.499, 82, 2.10M) & \small(211, 0.646, 55, 1.49M) & \small(149, 0.749, 41, 1.17M) \\\hhline{*{6}{-}}
# 256 & 10 & \small(4670010, 0.293, 163, 866K) & \small(3302196, 0.500, 82, 487K) & \small(2335005, 0.646, 55, 361K) & \small(1651097, 0.750, 41, 295K) \\
# & 15 & \small(1734902, 0.293, 163, 1.64M) & \small(1226760, 0.500, 82, 923K) & \small(867450, 0.646, 55, 670K) & \small(613380, 0.750, 41, 538K) \\
# & 20 & \small(644513, 0.293, 163, 2.69M) & \small(455739, 0.500, 82, 1.45M) & \small(322256, 0.646, 55, 1.04M) & \small(227869, 0.750, 41, 846K) \\
# & 25 & \small(239435, 0.293, 163, 3.98M) & \small(169306, 0.500, 82, 2.13M) & \small(119717, 0.646, 55, 1.51M) & \small(84652, 0.750, 41, 1.19M) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(m,\delta, \ell, |\pi|)$} \\
#
# nu = 20
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 20$} & \multicolumn{4}{c}{\cref{cor:fs-fri}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{80}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 15 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 20 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 192 & 10 & \small(1139, 0.293, 203, 1.02M) & \small(805, 0.500, 102, 590K) & \small(569, 0.646, 68, 435K) & \small(402, 0.750, 51, 358K) \\
# & 15 & \small(423, 0.292, 203, 2.00M) & \small(299, 0.499, 102, 1.10M) & \small(211, 0.646, 68, 813K) & \small(149, 0.749, 51, 657K) \\
# & 20 & \small(156, 0.291, 204, 3.30M) & \small(110, 0.498, 102, 1.77M) & \small(78, 0.644, 68, 1.27M) & \small(55, 0.748, 51, 1.01M) \\
# & 25 & \small(57, 0.287, 208, 5.00M) & \small(40, 0.494, 103, 2.63M) & \small(28, 0.640, 69, 1.87M) & \small(20, 0.744, 52, 1.49M) \\\hhline{*{6}{-}}
# 256 & 10 & \small(644513, 0.293, 203, 1.05M) & \small(455739, 0.500, 102, 605K) & \small(322256, 0.646, 68, 446K) & \small(227869, 0.750, 51, 366K) \\
# & 15 & \small(239435, 0.293, 203, 2.04M) & \small(169306, 0.500, 102, 1.12M) & \small(119717, 0.646, 68, 829K) & \small(84652, 0.750, 51, 669K) \\
# & 20 & \small(88949, 0.293, 203, 3.35M) & \small(62896, 0.500, 102, 1.81M) & \small(44474, 0.646, 68, 1.29M) & \small(31448, 0.750, 51, 1.03M) \\
# & 25 & \small(33044, 0.293, 203, 4.96M) & \small(23365, 0.500, 102, 2.65M) & \small(16521, 0.646, 68, 1.87M) & \small(11682, 0.750, 51, 1.48M) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(m,\delta, \ell, |\pi|)$} \\
#
# $2^{ 106 } \leq Q < 2^{ 107 }$
# nu = 40
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 40$} & \multicolumn{4}{c}{\cref{cor:fs-fri}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{60}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 15 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 20 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 192 & 10 & \small(1139, 0.293, 203, 1.02M) & \small(805, 0.500, 102, 590K) & \small(569, 0.646, 68, 435K) & \small(402, 0.750, 51, 358K) \\
# & 15 & \small(423, 0.292, 203, 2.00M) & \small(299, 0.499, 102, 1.10M) & \small(211, 0.646, 68, 813K) & \small(149, 0.749, 51, 657K) \\
# & 20 & \small(156, 0.291, 204, 3.30M) & \small(110, 0.498, 102, 1.77M) & \small(78, 0.644, 68, 1.27M) & \small(55, 0.748, 51, 1.01M) \\
# & 25 & \small(57, 0.287, 208, 5.00M) & \small(40, 0.494, 103, 2.63M) & \small(28, 0.640, 69, 1.87M) & \small(20, 0.744, 52, 1.49M) \\\hhline{*{6}{-}}
# 256 & 10 & \small(644513, 0.293, 203, 1.05M) & \small(455739, 0.500, 102, 605K) & \small(322256, 0.646, 68, 446K) & \small(227869, 0.750, 51, 366K) \\
# & 15 & \small(239435, 0.293, 203, 2.04M) & \small(169306, 0.500, 102, 1.12M) & \small(119717, 0.646, 68, 829K) & \small(84652, 0.750, 51, 669K) \\
# & 20 & \small(88949, 0.293, 203, 3.35M) & \small(62896, 0.500, 102, 1.81M) & \small(44474, 0.646, 68, 1.29M) & \small(31448, 0.750, 51, 1.03M) \\
# & 25 & \small(33044, 0.293, 203, 4.96M) & \small(23365, 0.500, 102, 2.65M) & \small(16521, 0.646, 68, 1.87M) & \small(11682, 0.750, 51, 1.48M) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(m,\delta, \ell, |\pi|)$} \\
#
# nu = 40
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 40$} & \multicolumn{4}{c}{\cref{cor:fs-fri}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{80}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 15 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 20 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 192 & 10 & \small(156, 0.291, 245, 1.23M) & \small(110, 0.498, 122, 705K) & \small(78, 0.644, 82, 525K) & \small(55, 0.748, 61, 429K) \\
# & 15 & \small(57, 0.287, 249, 2.45M) & \small(40, 0.494, 124, 1.33M) & \small(28, 0.640, 83, 992K) & \small(20, 0.744, 62, 799K) \\
# & 20 & \small(21, 0.276, 260, 4.21M) & \small(14, 0.482, 128, 2.23M) & \small(10, 0.629, 85, 1.58M) & \small(7, 0.732, 64, 1.27M) \\
# & 25 & \small(7, 0.242, 303, 7.28M) & \small(5, 0.450, 141, 3.60M) & \small(3, 0.588, 95, 2.57M) & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 256 & 10 & \small(88949, 0.293, 243, 1.26M) & \small(62896, 0.500, 122, 724K) & \small(44474, 0.646, 81, 531K) & \small(31448, 0.750, 61, 438K) \\
# & 15 & \small(33044, 0.293, 243, 2.45M) & \small(23365, 0.500, 122, 1.34M) & \small(16521, 0.646, 81, 987K) & \small(11682, 0.750, 61, 801K) \\
# & 20 & \small(12275, 0.293, 243, 4.01M) & \small(8680, 0.500, 122, 2.16M) & \small(6137, 0.646, 81, 1.53M) & \small(4339, 0.750, 61, 1.23M) \\
# & 25 & \small(4560, 0.293, 243, 5.93M) & \small(3224, 0.500, 122, 3.17M) & \small(2279, 0.646, 81, 2.23M) & \small(1611, 0.750, 61, 1.77M) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(m,\delta, \ell, |\pi|)$} \\
#
# $2^{ 96 } \leq Q < 2^{ 97 }$
# nu = 60
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 60$} & \multicolumn{4}{c}{\cref{cor:fs-fri}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{60}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 15 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 20 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 192 & 10 & \small(156, 0.291, 245, 1.23M) & \small(110, 0.498, 122, 705K) & \small(78, 0.644, 82, 525K) & \small(55, 0.748, 61, 429K) \\
# & 15 & \small(57, 0.287, 249, 2.45M) & \small(40, 0.494, 124, 1.33M) & \small(28, 0.640, 83, 992K) & \small(20, 0.744, 62, 799K) \\
# & 20 & \small(21, 0.276, 260, 4.21M) & \small(14, 0.482, 128, 2.23M) & \small(10, 0.629, 85, 1.58M) & \small(7, 0.732, 64, 1.27M) \\
# & 25 & \small(7, 0.242, 303, 7.28M) & \small(5, 0.450, 141, 3.60M) & \small(3, 0.588, 95, 2.57M) & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 256 & 10 & \small(88949, 0.293, 243, 1.26M) & \small(62896, 0.500, 122, 724K) & \small(44474, 0.646, 81, 531K) & \small(31448, 0.750, 61, 438K) \\
# & 15 & \small(33044, 0.293, 243, 2.45M) & \small(23365, 0.500, 122, 1.34M) & \small(16521, 0.646, 81, 987K) & \small(11682, 0.750, 61, 801K) \\
# & 20 & \small(12275, 0.293, 243, 4.01M) & \small(8680, 0.500, 122, 2.16M) & \small(6137, 0.646, 81, 1.53M) & \small(4339, 0.750, 61, 1.23M) \\
# & 25 & \small(4560, 0.293, 243, 5.93M) & \small(3224, 0.500, 122, 3.17M) & \small(2279, 0.646, 81, 2.23M) & \small(1611, 0.750, 61, 1.77M) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(m,\delta, \ell, |\pi|)$} \\
#
# nu = 60
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 60$} & \multicolumn{4}{c}{\cref{cor:fs-fri}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{80}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 15 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 20 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 192 & 10 & \small(21, 0.276, 303, 1.53M) & \small(14, 0.482, 149, 861K) & \small(10, 0.629, 99, 634K) & \small(7, 0.732, 75, 527K) \\
# & 15 & \small(7, 0.242, 353, 3.47M) & \small(5, 0.450, 164, 1.76M) & \small(3, 0.588, 111, 1.30M) & \cellcolor{lightgray} \\
# & 20 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 256 & 10 & \small(12275, 0.293, 283, 1.47M) & \small(8680, 0.500, 142, 843K) & \small(6137, 0.646, 95, 623K) & \small(4339, 0.750, 71, 510K) \\
# & 15 & \small(4560, 0.293, 283, 2.85M) & \small(3224, 0.500, 142, 1.56M) & \small(2279, 0.646, 95, 1.13M) & \small(1611, 0.750, 71, 932K) \\
# & 20 & \small(1693, 0.293, 283, 4.66M) & \small(1197, 0.500, 142, 2.51M) & \small(846, 0.646, 95, 1.80M) & \small(598, 0.750, 71, 1.43M) \\
# & 25 & \small(628, 0.292, 283, 6.91M) & \small(444, 0.499, 142, 3.68M) & \small(314, 0.646, 95, 2.61M) & \small(222, 0.749, 71, 2.06M) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(m,\delta, \ell, |\pi|)$} \\
#
# $2^{ 86 } \leq Q < 2^{ 87 }$
# nu = 80
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 80$} & \multicolumn{4}{c}{\cref{cor:fs-fri}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{60}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 15 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 20 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 192 & 10 & \small(21, 0.276, 303, 1.53M) & \small(14, 0.482, 149, 861K) & \small(10, 0.629, 99, 634K) & \small(7, 0.732, 75, 527K) \\
# & 15 & \small(7, 0.242, 353, 3.47M) & \small(5, 0.450, 164, 1.76M) & \small(3, 0.588, 111, 1.30M) & \cellcolor{lightgray} \\
# & 20 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 256 & 10 & \small(12275, 0.293, 283, 1.47M) & \small(8680, 0.500, 142, 843K) & \small(6137, 0.646, 95, 623K) & \small(4339, 0.750, 71, 510K) \\
# & 15 & \small(4560, 0.293, 283, 2.85M) & \small(3224, 0.500, 142, 1.56M) & \small(2279, 0.646, 95, 1.13M) & \small(1611, 0.750, 71, 932K) \\
# & 20 & \small(1693, 0.293, 283, 4.66M) & \small(1197, 0.500, 142, 2.51M) & \small(846, 0.646, 95, 1.80M) & \small(598, 0.750, 71, 1.43M) \\
# & 25 & \small(628, 0.292, 283, 6.91M) & \small(444, 0.499, 142, 3.68M) & \small(314, 0.646, 95, 2.61M) & \small(222, 0.749, 71, 2.06M) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(m,\delta, \ell, |\pi|)$} \\
#
# nu = 80
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 80$} & \multicolumn{4}{c}{\cref{cor:fs-fri}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{80}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 15 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 20 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 192 & 10 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 15 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 20 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 256 & 10 & \small(1693, 0.293, 323, 1.68M) & \small(1197, 0.500, 162, 962K) & \small(846, 0.646, 108, 709K) & \small(598, 0.750, 81, 582K) \\
# & 15 & \small(628, 0.292, 323, 3.25M) & \small(444, 0.499, 162, 1.78M) & \small(314, 0.646, 108, 1.29M) & \small(222, 0.749, 81, 1.04M) \\
# & 20 & \small(233, 0.291, 325, 5.36M) & \small(164, 0.498, 162, 2.87M) & \small(116, 0.645, 108, 2.04M) & \small(82, 0.748, 81, 1.63M) \\
# & 25 & \small(86, 0.289, 328, 8.01M) & \small(60, 0.496, 163, 4.23M) & \small(42, 0.642, 109, 2.99M) & \small(30, 0.746, 82, 2.38M) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(m,\delta, \ell, |\pi|)$} \\
#
# ===== Conjectured Security Calculations 1 =====
# $2^{ 116 } \leq Q < 2^{ 117 }$
# nu = 20
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 20$} & \multicolumn{4}{c}{\cref{conj:fri-1}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{60}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \small(0.500, 82, 410K) & \small(0.750, 41, 230K) & \small(0.875, 28, 175K) & \small(0.937, 21, 144K) \\
# & 15 & \small(0.500, 82, 807K) & \small(0.750, 41, 442K) & \small(0.875, 28, 328K) & \small(0.937, 21, 266K) \\
# & 20 & \small(0.500, 82, 1.30M) & \small(0.750, 41, 718K) & \small(0.875, 28, 525K) & \small(0.937, 21, 420K) \\
# & 25 & \small(0.500, 82, 1.94M) & \small(0.750, 41, 1.03M) & \small(0.875, 28, 766K) & \small(0.937, 21, 607K) \\\hhline{*{6}{-}}
# 192 & 10 & \small(0.500, 82, 423K) & \small(0.750, 41, 237K) & \small(0.875, 28, 179K) & \small(0.937, 21, 147K) \\
# & 15 & \small(0.500, 82, 826K) & \small(0.750, 41, 452K) & \small(0.875, 28, 335K) & \small(0.937, 21, 271K) \\
# & 20 & \small(0.500, 82, 1.33M) & \small(0.750, 41, 730K) & \small(0.875, 28, 534K) & \small(0.937, 21, 427K) \\
# & 25 & \small(0.500, 82, 1.97M) & \small(0.750, 41, 1.05M) & \small(0.875, 28, 777K) & \small(0.937, 21, 616K) \\\hhline{*{6}{-}}
# 256 & 10 & \small(0.500, 82, 435K) & \small(0.750, 41, 243K) & \small(0.875, 28, 184K) & \small(0.937, 21, 151K) \\
# & 15 & \small(0.500, 82, 846K) & \small(0.750, 41, 461K) & \small(0.875, 28, 341K) & \small(0.937, 21, 276K) \\
# & 20 & \small(0.500, 82, 1.35M) & \small(0.750, 41, 743K) & \small(0.875, 28, 543K) & \small(0.937, 21, 433K) \\
# & 25 & \small(0.500, 82, 2.00M) & \small(0.750, 41, 1.06M) & \small(0.875, 28, 788K) & \small(0.937, 21, 624K) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(\delta, \ell, |\pi|)$} \\
#
# nu = 20
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 20$} & \multicolumn{4}{c}{\cref{conj:fri-1}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{80}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \small(0.500, 102, 510K) & \small(0.750, 51, 287K) & \small(0.875, 34, 212K) & \small(0.936, 26, 179K) \\
# & 15 & \small(0.499, 102, 1004K) & \small(0.746, 52, 561K) & \small(0.859, 36, 422K) & \cellcolor{lightgray} \\
# & 20 & \small(0.469, 111, 1.76M) & \small(0.625, 72, 1.23M) & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 192 & 10 & \small(0.500, 102, 526K) & \small(0.750, 51, 295K) & \small(0.875, 34, 218K) & \small(0.937, 26, 183K) \\
# & 15 & \small(0.500, 102, 1.00M) & \small(0.750, 51, 562K) & \small(0.875, 34, 406K) & \small(0.937, 26, 335K) \\
# & 20 & \small(0.500, 102, 1.65M) & \small(0.750, 51, 909K) & \small(0.875, 34, 648K) & \small(0.937, 26, 528K) \\
# & 25 & \small(0.500, 102, 2.45M) & \small(0.750, 51, 1.30M) & \small(0.875, 34, 943K) & \small(0.937, 26, 762K) \\\hhline{*{6}{-}}
# 256 & 10 & \small(0.500, 102, 542K) & \small(0.750, 51, 303K) & \small(0.875, 34, 223K) & \small(0.937, 26, 187K) \\
# & 15 & \small(0.500, 102, 1.03M) & \small(0.750, 51, 574K) & \small(0.875, 34, 414K) & \small(0.937, 26, 341K) \\
# & 20 & \small(0.500, 102, 1.68M) & \small(0.750, 51, 925K) & \small(0.875, 34, 659K) & \small(0.937, 26, 536K) \\
# & 25 & \small(0.500, 102, 2.49M) & \small(0.750, 51, 1.32M) & \small(0.875, 34, 957K) & \small(0.937, 26, 772K) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(\delta, \ell, |\pi|)$} \\
#
# $2^{ 106 } \leq Q < 2^{ 107 }$
# nu = 40
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 40$} & \multicolumn{4}{c}{\cref{conj:fri-1}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{60}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \small(0.500, 102, 510K) & \small(0.750, 51, 287K) & \small(0.875, 34, 212K) & \small(0.936, 26, 179K) \\
# & 15 & \small(0.499, 102, 1004K) & \small(0.746, 52, 561K) & \small(0.859, 36, 422K) & \cellcolor{lightgray} \\
# & 20 & \small(0.469, 111, 1.76M) & \small(0.625, 72, 1.23M) & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 192 & 10 & \small(0.500, 102, 526K) & \small(0.750, 51, 295K) & \small(0.875, 34, 218K) & \small(0.937, 26, 183K) \\
# & 15 & \small(0.500, 102, 1.00M) & \small(0.750, 51, 562K) & \small(0.875, 34, 406K) & \small(0.937, 26, 335K) \\
# & 20 & \small(0.500, 102, 1.65M) & \small(0.750, 51, 909K) & \small(0.875, 34, 648K) & \small(0.937, 26, 528K) \\
# & 25 & \small(0.500, 102, 2.45M) & \small(0.750, 51, 1.30M) & \small(0.875, 34, 943K) & \small(0.937, 26, 762K) \\\hhline{*{6}{-}}
# 256 & 10 & \small(0.500, 102, 542K) & \small(0.750, 51, 303K) & \small(0.875, 34, 223K) & \small(0.937, 26, 187K) \\
# & 15 & \small(0.500, 102, 1.03M) & \small(0.750, 51, 574K) & \small(0.875, 34, 414K) & \small(0.937, 26, 341K) \\
# & 20 & \small(0.500, 102, 1.68M) & \small(0.750, 51, 925K) & \small(0.875, 34, 659K) & \small(0.937, 26, 536K) \\
# & 25 & \small(0.500, 102, 2.49M) & \small(0.750, 51, 1.32M) & \small(0.875, 34, 957K) & \small(0.937, 26, 772K) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(\delta, \ell, |\pi|)$} \\
#
# nu = 40
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 40$} & \multicolumn{4}{c}{\cref{conj:fri-1}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{80}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 15 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 20 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 192 & 10 & \small(0.500, 122, 629K) & \small(0.750, 61, 352K) & \small(0.875, 41, 262K) & \small(0.937, 31, 218K) \\
# & 15 & \small(0.500, 122, 1.20M) & \small(0.750, 61, 672K) & \small(0.875, 41, 490K) & \small(0.937, 31, 400K) \\
# & 20 & \small(0.500, 122, 1.97M) & \small(0.750, 61, 1.06M) & \small(0.875, 41, 782K) & \small(0.937, 31, 630K) \\
# & 25 & \small(0.500, 122, 2.93M) & \small(0.750, 61, 1.56M) & \small(0.875, 41, 1.11M) & \small(0.937, 31, 909K) \\\hhline{*{6}{-}}
# 256 & 10 & \small(0.500, 122, 648K) & \small(0.750, 61, 362K) & \small(0.875, 41, 269K) & \small(0.937, 31, 223K) \\
# & 15 & \small(0.500, 122, 1.23M) & \small(0.750, 61, 686K) & \small(0.875, 41, 500K) & \small(0.937, 31, 407K) \\
# & 20 & \small(0.500, 122, 2.01M) & \small(0.750, 61, 1.08M) & \small(0.875, 41, 795K) & \small(0.937, 31, 640K) \\
# & 25 & \small(0.500, 122, 2.98M) & \small(0.750, 61, 1.58M) & \small(0.875, 41, 1.13M) & \small(0.937, 31, 921K) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(\delta, \ell, |\pi|)$} \\
#
# $2^{ 96 } \leq Q < 2^{ 97 }$
# nu = 60
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 60$} & \multicolumn{4}{c}{\cref{conj:fri-1}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{60}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 15 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 20 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 192 & 10 & \small(0.500, 122, 629K) & \small(0.750, 61, 352K) & \small(0.875, 41, 262K) & \small(0.937, 31, 218K) \\
# & 15 & \small(0.500, 122, 1.20M) & \small(0.750, 61, 672K) & \small(0.875, 41, 490K) & \small(0.937, 31, 400K) \\
# & 20 & \small(0.500, 122, 1.97M) & \small(0.750, 61, 1.06M) & \small(0.875, 41, 782K) & \small(0.937, 31, 630K) \\
# & 25 & \small(0.500, 122, 2.93M) & \small(0.750, 61, 1.56M) & \small(0.875, 41, 1.11M) & \small(0.937, 31, 909K) \\\hhline{*{6}{-}}
# 256 & 10 & \small(0.500, 122, 648K) & \small(0.750, 61, 362K) & \small(0.875, 41, 269K) & \small(0.937, 31, 223K) \\
# & 15 & \small(0.500, 122, 1.23M) & \small(0.750, 61, 686K) & \small(0.875, 41, 500K) & \small(0.937, 31, 407K) \\
# & 20 & \small(0.500, 122, 2.01M) & \small(0.750, 61, 1.08M) & \small(0.875, 41, 795K) & \small(0.937, 31, 640K) \\
# & 25 & \small(0.500, 122, 2.98M) & \small(0.750, 61, 1.58M) & \small(0.875, 41, 1.13M) & \small(0.937, 31, 921K) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(\delta, \ell, |\pi|)$} \\
#
# nu = 60
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 60$} & \multicolumn{4}{c}{\cref{conj:fri-1}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{80}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 15 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 20 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 192 & 10 & \small(0.500, 142, 732K) & \small(0.750, 71, 410K) & \small(0.875, 48, 307K) & \small(0.937, 36, 253K) \\
# & 15 & \small(0.500, 142, 1.40M) & \small(0.750, 71, 782K) & \small(0.875, 48, 574K) & \small(0.937, 36, 464K) \\
# & 20 & \small(0.500, 142, 2.30M) & \small(0.750, 71, 1.24M) & \small(0.875, 48, 915K) & \small(0.937, 36, 731K) \\
# & 25 & \small(0.500, 142, 3.41M) & \small(0.750, 71, 1.82M) & \small(0.875, 48, 1.30M) & \small(0.937, 36, 1.03M) \\\hhline{*{6}{-}}
# 256 & 10 & \small(0.500, 142, 754K) & \small(0.750, 71, 421K) & \small(0.875, 48, 315K) & \small(0.937, 36, 259K) \\
# & 15 & \small(0.500, 142, 1.43M) & \small(0.750, 71, 799K) & \small(0.875, 48, 585K) & \small(0.937, 36, 473K) \\
# & 20 & \small(0.500, 142, 2.34M) & \small(0.750, 71, 1.26M) & \small(0.875, 48, 930K) & \small(0.937, 36, 743K) \\
# & 25 & \small(0.500, 142, 3.47M) & \small(0.750, 71, 1.84M) & \small(0.875, 48, 1.32M) & \small(0.937, 36, 1.04M) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(\delta, \ell, |\pi|)$} \\
#
# $2^{ 86 } \leq Q < 2^{ 87 }$
# nu = 80
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 80$} & \multicolumn{4}{c}{\cref{conj:fri-1}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{60}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 15 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 20 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 192 & 10 & \small(0.500, 142, 732K) & \small(0.750, 71, 410K) & \small(0.875, 48, 307K) & \small(0.937, 36, 253K) \\
# & 15 & \small(0.500, 142, 1.40M) & \small(0.750, 71, 782K) & \small(0.875, 48, 574K) & \small(0.937, 36, 464K) \\
# & 20 & \small(0.500, 142, 2.30M) & \small(0.750, 71, 1.24M) & \small(0.875, 48, 915K) & \small(0.937, 36, 731K) \\
# & 25 & \small(0.500, 142, 3.41M) & \small(0.750, 71, 1.82M) & \small(0.875, 48, 1.30M) & \small(0.937, 36, 1.03M) \\\hhline{*{6}{-}}
# 256 & 10 & \small(0.500, 142, 754K) & \small(0.750, 71, 421K) & \small(0.875, 48, 315K) & \small(0.937, 36, 259K) \\
# & 15 & \small(0.500, 142, 1.43M) & \small(0.750, 71, 799K) & \small(0.875, 48, 585K) & \small(0.937, 36, 473K) \\
# & 20 & \small(0.500, 142, 2.34M) & \small(0.750, 71, 1.26M) & \small(0.875, 48, 930K) & \small(0.937, 36, 743K) \\
# & 25 & \small(0.500, 142, 3.47M) & \small(0.750, 71, 1.84M) & \small(0.875, 48, 1.32M) & \small(0.937, 36, 1.04M) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(\delta, \ell, |\pi|)$} \\
#
# nu = 80
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 80$} & \multicolumn{4}{c}{\cref{conj:fri-1}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{80}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 15 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 20 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 192 & 10 & \small(0.500, 162, 835K) & \small(0.750, 81, 468K) & \small(0.875, 54, 346K) & \small(0.937, 41, 288K) \\
# & 15 & \small(0.500, 162, 1.59M) & \small(0.750, 81, 892K) & \small(0.874, 54, 645K) & \small(0.934, 42, 541K) \\
# & 20 & \small(0.498, 162, 2.62M) & \small(0.742, 83, 1.44M) & \small(0.844, 61, 1.14M) & \cellcolor{lightgray} \\
# & 25 & \small(0.437, 194, 4.66M) & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 256 & 10 & \small(0.500, 162, 860K) & \small(0.750, 81, 481K) & \small(0.875, 54, 354K) & \small(0.937, 41, 295K) \\
# & 15 & \small(0.500, 162, 1.63M) & \small(0.750, 81, 911K) & \small(0.875, 54, 658K) & \small(0.937, 41, 538K) \\
# & 20 & \small(0.500, 162, 2.67M) & \small(0.750, 81, 1.43M) & \small(0.875, 54, 1.02M) & \small(0.937, 41, 846K) \\
# & 25 & \small(0.500, 162, 3.96M) & \small(0.750, 81, 2.10M) & \small(0.875, 54, 1.48M) & \small(0.937, 41, 1.19M) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(\delta, \ell, |\pi|)$} \\
#
# ===== Conjectured Security Calculations 2 =====
# $2^{ 116 } \leq Q < 2^{ 117 }$
# nu = 20
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 20$} & \multicolumn{4}{c}{\cref{conj:fri-2}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{60}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \small(0.500, 82, 410K) & \small(0.750, 41, 230K) & \small(0.875, 28, 175K) & \small(0.938, 21, 144K) \\
# & 15 & \small(0.500, 82, 807K) & \small(0.750, 41, 442K) & \small(0.875, 28, 328K) & \small(0.938, 21, 266K) \\
# & 20 & \small(0.500, 82, 1.30M) & \small(0.750, 41, 718K) & \small(0.875, 28, 525K) & \small(0.938, 21, 420K) \\
# & 25 & \small(0.500, 82, 1.94M) & \small(0.750, 41, 1.03M) & \small(0.875, 28, 766K) & \small(0.938, 21, 607K) \\\hhline{*{6}{-}}
# 192 & 10 & \small(0.500, 82, 423K) & \small(0.750, 41, 237K) & \small(0.875, 28, 179K) & \small(0.938, 21, 147K) \\
# & 15 & \small(0.500, 82, 826K) & \small(0.750, 41, 452K) & \small(0.875, 28, 335K) & \small(0.938, 21, 271K) \\
# & 20 & \small(0.500, 82, 1.33M) & \small(0.750, 41, 730K) & \small(0.875, 28, 534K) & \small(0.938, 21, 427K) \\
# & 25 & \small(0.500, 82, 1.97M) & \small(0.750, 41, 1.05M) & \small(0.875, 28, 777K) & \small(0.938, 21, 616K) \\\hhline{*{6}{-}}
# 256 & 10 & \small(0.500, 82, 435K) & \small(0.750, 41, 243K) & \small(0.875, 28, 184K) & \small(0.938, 21, 151K) \\
# & 15 & \small(0.500, 82, 846K) & \small(0.750, 41, 461K) & \small(0.875, 28, 341K) & \small(0.938, 21, 276K) \\
# & 20 & \small(0.500, 82, 1.35M) & \small(0.750, 41, 743K) & \small(0.875, 28, 543K) & \small(0.938, 21, 433K) \\
# & 25 & \small(0.500, 82, 2.00M) & \small(0.750, 41, 1.06M) & \small(0.875, 28, 788K) & \small(0.938, 21, 624K) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(\delta, \ell, |\pi|)$} \\
#
# nu = 20
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 20$} & \multicolumn{4}{c}{\cref{conj:fri-2}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{80}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \small(0.500, 102, 510K) & \small(0.750, 51, 287K) & \small(0.875, 34, 212K) & \small(0.938, 26, 179K) \\
# & 15 & \small(0.500, 102, 1004K) & \small(0.750, 51, 550K) & \small(0.875, 34, 398K) & \small(0.938, 26, 329K) \\
# & 20 & \small(0.500, 102, 1.62M) & \small(0.750, 51, 893K) & \small(0.875, 34, 638K) & \small(0.938, 26, 520K) \\
# & 25 & \small(0.500, 102, 2.41M) & \small(0.750, 51, 1.28M) & \small(0.875, 34, 930K) & \small(0.938, 26, 752K) \\\hhline{*{6}{-}}
# 192 & 10 & \small(0.500, 102, 526K) & \small(0.750, 51, 295K) & \small(0.875, 34, 218K) & \small(0.938, 26, 183K) \\
# & 15 & \small(0.500, 102, 1.00M) & \small(0.750, 51, 562K) & \small(0.875, 34, 406K) & \small(0.938, 26, 335K) \\
# & 20 & \small(0.500, 102, 1.65M) & \small(0.750, 51, 909K) & \small(0.875, 34, 648K) & \small(0.938, 26, 528K) \\
# & 25 & \small(0.500, 102, 2.45M) & \small(0.750, 51, 1.30M) & \small(0.875, 34, 943K) & \small(0.938, 26, 762K) \\\hhline{*{6}{-}}
# 256 & 10 & \small(0.500, 102, 542K) & \small(0.750, 51, 303K) & \small(0.875, 34, 223K) & \small(0.938, 26, 187K) \\
# & 15 & \small(0.500, 102, 1.03M) & \small(0.750, 51, 574K) & \small(0.875, 34, 414K) & \small(0.938, 26, 341K) \\
# & 20 & \small(0.500, 102, 1.68M) & \small(0.750, 51, 925K) & \small(0.875, 34, 659K) & \small(0.938, 26, 536K) \\
# & 25 & \small(0.500, 102, 2.49M) & \small(0.750, 51, 1.32M) & \small(0.875, 34, 957K) & \small(0.938, 26, 772K) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(\delta, \ell, |\pi|)$} \\
#
# $2^{ 106 } \leq Q < 2^{ 107 }$
# nu = 40
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 40$} & \multicolumn{4}{c}{\cref{conj:fri-2}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{60}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \small(0.500, 102, 510K) & \small(0.750, 51, 287K) & \small(0.875, 34, 212K) & \small(0.938, 26, 179K) \\
# & 15 & \small(0.500, 102, 1004K) & \small(0.750, 51, 550K) & \small(0.875, 34, 398K) & \small(0.938, 26, 329K) \\
# & 20 & \small(0.500, 102, 1.62M) & \small(0.750, 51, 893K) & \small(0.875, 34, 638K) & \small(0.938, 26, 520K) \\
# & 25 & \small(0.500, 102, 2.41M) & \small(0.750, 51, 1.28M) & \small(0.875, 34, 930K) & \small(0.938, 26, 752K) \\\hhline{*{6}{-}}
# 192 & 10 & \small(0.500, 102, 526K) & \small(0.750, 51, 295K) & \small(0.875, 34, 218K) & \small(0.938, 26, 183K) \\
# & 15 & \small(0.500, 102, 1.00M) & \small(0.750, 51, 562K) & \small(0.875, 34, 406K) & \small(0.938, 26, 335K) \\
# & 20 & \small(0.500, 102, 1.65M) & \small(0.750, 51, 909K) & \small(0.875, 34, 648K) & \small(0.938, 26, 528K) \\
# & 25 & \small(0.500, 102, 2.45M) & \small(0.750, 51, 1.30M) & \small(0.875, 34, 943K) & \small(0.938, 26, 762K) \\\hhline{*{6}{-}}
# 256 & 10 & \small(0.500, 102, 542K) & \small(0.750, 51, 303K) & \small(0.875, 34, 223K) & \small(0.938, 26, 187K) \\
# & 15 & \small(0.500, 102, 1.03M) & \small(0.750, 51, 574K) & \small(0.875, 34, 414K) & \small(0.938, 26, 341K) \\
# & 20 & \small(0.500, 102, 1.68M) & \small(0.750, 51, 925K) & \small(0.875, 34, 659K) & \small(0.938, 26, 536K) \\
# & 25 & \small(0.500, 102, 2.49M) & \small(0.750, 51, 1.32M) & \small(0.875, 34, 957K) & \small(0.938, 26, 772K) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(\delta, \ell, |\pi|)$} \\
#
# nu = 40
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 40$} & \multicolumn{4}{c}{\cref{conj:fri-2}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{80}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \small(0.500, 122, 610K) & \small(0.750, 61, 343K) & \small(0.875, 41, 256K) & \small(0.938, 31, 213K) \\
# & 15 & \small(0.500, 122, 1.17M) & \small(0.750, 61, 658K) & \small(0.875, 41, 480K) & \small(0.938, 31, 392K) \\
# & 20 & \small(0.500, 122, 1.94M) & \small(0.750, 61, 1.04M) & \small(0.875, 41, 769K) & \small(0.938, 31, 620K) \\
# & 25 & \small(0.500, 122, 2.89M) & \small(0.750, 61, 1.54M) & \small(0.875, 41, 1.10M) & \small(0.938, 31, 896K) \\\hhline{*{6}{-}}
# 192 & 10 & \small(0.500, 122, 629K) & \small(0.750, 61, 352K) & \small(0.875, 41, 262K) & \small(0.938, 31, 218K) \\
# & 15 & \small(0.500, 122, 1.20M) & \small(0.750, 61, 672K) & \small(0.875, 41, 490K) & \small(0.938, 31, 400K) \\
# & 20 & \small(0.500, 122, 1.97M) & \small(0.750, 61, 1.06M) & \small(0.875, 41, 782K) & \small(0.938, 31, 630K) \\
# & 25 & \small(0.500, 122, 2.93M) & \small(0.750, 61, 1.56M) & \small(0.875, 41, 1.11M) & \small(0.938, 31, 909K) \\\hhline{*{6}{-}}
# 256 & 10 & \small(0.500, 122, 648K) & \small(0.750, 61, 362K) & \small(0.875, 41, 269K) & \small(0.938, 31, 223K) \\
# & 15 & \small(0.500, 122, 1.23M) & \small(0.750, 61, 686K) & \small(0.875, 41, 500K) & \small(0.938, 31, 407K) \\
# & 20 & \small(0.500, 122, 2.01M) & \small(0.750, 61, 1.08M) & \small(0.875, 41, 795K) & \small(0.938, 31, 640K) \\
# & 25 & \small(0.500, 122, 2.98M) & \small(0.750, 61, 1.58M) & \small(0.875, 41, 1.13M) & \small(0.938, 31, 921K) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(\delta, \ell, |\pi|)$} \\
#
# $2^{ 96 } \leq Q < 2^{ 97 }$
# nu = 60
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 60$} & \multicolumn{4}{c}{\cref{conj:fri-2}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{60}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \small(0.500, 122, 610K) & \small(0.750, 61, 343K) & \small(0.875, 41, 256K) & \small(0.938, 31, 213K) \\
# & 15 & \small(0.500, 122, 1.17M) & \small(0.750, 61, 658K) & \small(0.875, 41, 480K) & \small(0.938, 31, 392K) \\
# & 20 & \small(0.500, 122, 1.94M) & \small(0.750, 61, 1.04M) & \small(0.875, 41, 769K) & \small(0.938, 31, 620K) \\
# & 25 & \small(0.500, 122, 2.89M) & \small(0.750, 61, 1.54M) & \small(0.875, 41, 1.10M) & \small(0.938, 31, 896K) \\\hhline{*{6}{-}}
# 192 & 10 & \small(0.500, 122, 629K) & \small(0.750, 61, 352K) & \small(0.875, 41, 262K) & \small(0.938, 31, 218K) \\
# & 15 & \small(0.500, 122, 1.20M) & \small(0.750, 61, 672K) & \small(0.875, 41, 490K) & \small(0.938, 31, 400K) \\
# & 20 & \small(0.500, 122, 1.97M) & \small(0.750, 61, 1.06M) & \small(0.875, 41, 782K) & \small(0.938, 31, 630K) \\
# & 25 & \small(0.500, 122, 2.93M) & \small(0.750, 61, 1.56M) & \small(0.875, 41, 1.11M) & \small(0.938, 31, 909K) \\\hhline{*{6}{-}}
# 256 & 10 & \small(0.500, 122, 648K) & \small(0.750, 61, 362K) & \small(0.875, 41, 269K) & \small(0.938, 31, 223K) \\
# & 15 & \small(0.500, 122, 1.23M) & \small(0.750, 61, 686K) & \small(0.875, 41, 500K) & \small(0.938, 31, 407K) \\
# & 20 & \small(0.500, 122, 2.01M) & \small(0.750, 61, 1.08M) & \small(0.875, 41, 795K) & \small(0.938, 31, 640K) \\
# & 25 & \small(0.500, 122, 2.98M) & \small(0.750, 61, 1.58M) & \small(0.875, 41, 1.13M) & \small(0.938, 31, 921K) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(\delta, \ell, |\pi|)$} \\
#
# nu = 60
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 60$} & \multicolumn{4}{c}{\cref{conj:fri-2}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{80}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 15 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 20 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 192 & 10 & \small(0.500, 142, 732K) & \small(0.750, 71, 410K) & \small(0.875, 48, 307K) & \small(0.938, 36, 253K) \\
# & 15 & \small(0.500, 142, 1.40M) & \small(0.750, 71, 782K) & \small(0.875, 48, 574K) & \small(0.938, 36, 464K) \\
# & 20 & \small(0.500, 142, 2.30M) & \small(0.750, 71, 1.24M) & \small(0.875, 48, 915K) & \small(0.938, 36, 731K) \\
# & 25 & \small(0.500, 142, 3.41M) & \small(0.750, 71, 1.82M) & \small(0.875, 48, 1.30M) & \small(0.938, 36, 1.03M) \\\hhline{*{6}{-}}
# 256 & 10 & \small(0.500, 142, 754K) & \small(0.750, 71, 421K) & \small(0.875, 48, 315K) & \small(0.938, 36, 259K) \\
# & 15 & \small(0.500, 142, 1.43M) & \small(0.750, 71, 799K) & \small(0.875, 48, 585K) & \small(0.938, 36, 473K) \\
# & 20 & \small(0.500, 142, 2.34M) & \small(0.750, 71, 1.26M) & \small(0.875, 48, 930K) & \small(0.938, 36, 743K) \\
# & 25 & \small(0.500, 142, 3.47M) & \small(0.750, 71, 1.84M) & \small(0.875, 48, 1.32M) & \small(0.938, 36, 1.04M) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(\delta, \ell, |\pi|)$} \\
#
# $2^{ 86 } \leq Q < 2^{ 87 }$
# nu = 80
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 80$} & \multicolumn{4}{c}{\cref{conj:fri-2}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{60}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 15 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 20 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 192 & 10 & \small(0.500, 142, 732K) & \small(0.750, 71, 410K) & \small(0.875, 48, 307K) & \small(0.938, 36, 253K) \\
# & 15 & \small(0.500, 142, 1.40M) & \small(0.750, 71, 782K) & \small(0.875, 48, 574K) & \small(0.938, 36, 464K) \\
# & 20 & \small(0.500, 142, 2.30M) & \small(0.750, 71, 1.24M) & \small(0.875, 48, 915K) & \small(0.938, 36, 731K) \\
# & 25 & \small(0.500, 142, 3.41M) & \small(0.750, 71, 1.82M) & \small(0.875, 48, 1.30M) & \small(0.938, 36, 1.03M) \\\hhline{*{6}{-}}
# 256 & 10 & \small(0.500, 142, 754K) & \small(0.750, 71, 421K) & \small(0.875, 48, 315K) & \small(0.938, 36, 259K) \\
# & 15 & \small(0.500, 142, 1.43M) & \small(0.750, 71, 799K) & \small(0.875, 48, 585K) & \small(0.938, 36, 473K) \\
# & 20 & \small(0.500, 142, 2.34M) & \small(0.750, 71, 1.26M) & \small(0.875, 48, 930K) & \small(0.938, 36, 743K) \\
# & 25 & \small(0.500, 142, 3.47M) & \small(0.750, 71, 1.84M) & \small(0.875, 48, 1.32M) & \small(0.938, 36, 1.04M) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(\delta, \ell, |\pi|)$} \\
#
# nu = 80
# \hhline{|t:==:t|}
# \multicolumn{2}{||c||}{$\nu = 80$} & \multicolumn{4}{c}{\cref{conj:fri-2}} \\\hhline{||~~||----}
# \multicolumn{2}{||c||}{$Q = 2^{80}$} & $\rho = 1/2$ & $\rho = 1/4$ & $\rho = 1/8$ & $\rho = 1/16$ \\\hhline{|b:==:b|*{4}{=|}}
# 128 & 10 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 15 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 20 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\
# & 25 & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} & \cellcolor{lightgray} \\\hhline{*{6}{-}}
# 192 & 10 & \small(0.500, 162, 835K) & \small(0.750, 81, 468K) & \small(0.875, 54, 346K) & \small(0.938, 41, 288K) \\
# & 15 & \small(0.500, 162, 1.59M) & \small(0.750, 81, 892K) & \small(0.875, 54, 645K) & \small(0.938, 41, 529K) \\
# & 20 & \small(0.500, 162, 2.62M) & \small(0.750, 81, 1.41M) & \small(0.875, 54, 1.01M) & \small(0.938, 41, 833K) \\
# & 25 & \small(0.500, 162, 3.89M) & \small(0.750, 81, 2.07M) & \small(0.875, 54, 1.46M) & \small(0.938, 41, 1.17M) \\\hhline{*{6}{-}}
# 256 & 10 & \small(0.500, 162, 860K) & \small(0.750, 81, 481K) & \small(0.875, 54, 354K) & \small(0.938, 41, 295K) \\
# & 15 & \small(0.500, 162, 1.63M) & \small(0.750, 81, 911K) & \small(0.875, 54, 658K) & \small(0.938, 41, 538K) \\
# & 20 & \small(0.500, 162, 2.67M) & \small(0.750, 81, 1.43M) & \small(0.875, 54, 1.02M) & \small(0.938, 41, 846K) \\
# & 25 & \small(0.500, 162, 3.96M) & \small(0.750, 81, 2.10M) & \small(0.875, 54, 1.48M) & \small(0.938, 41, 1.19M) \\\hhline{*{6}{-}}
# $\log|\bbF|$ & $k$ & \multicolumn{4}{c}{$(\delta, \ell, |\pi|)$} \\
